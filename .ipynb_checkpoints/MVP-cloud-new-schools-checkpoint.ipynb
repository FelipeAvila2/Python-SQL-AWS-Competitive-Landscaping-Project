# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'la-capsule' : 10853,
'app-academy' : 10525,
'springboard' : 11035,
'metis' : 10886,
'practicum-by-yandex' : 11225,
'le-wagon' : 10868,
'academia-de-codigo' :10494 ,
'react-graphql-academy' : 10972
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
# comments = []

# for school in schools.keys():
#    print(school)
#    comments.append(get_comments_school(school))
    
comments = [get_comments_school(key) for key in schools.keys()]

comments = pd.concat(comments)
comments.sample(50)
# Out:
#           id                     name  anonymous       hostProgramName  \
# 476   246332              Axel Dahlin      False  Software Engineering
# 125   266749              Andrew Chen      False  Software Engineering
# 951   233391                Anonymous      False                  None
# 726   243120                     Jeff      False  Software Engineering
# 754   245839           Onyema Nwokolo      False          UX/UI Design
# 1     278202               Kora Feder      False                  None
# 16    274707        Ahmed Eldemerdash      False                  None
# 272   261637                Anonymous       True  Software Engineering
# 267   261644                Anonymous       True  Software Engineering
# 1129  246859    Richard van den Broek      False  Software Engineering
# 871   252226        Patricia Vila Luz      False  Software Engineering
# 574   244369         Benjamin Rothman      False  Software Engineering
# 485   233187             Jose Morales      False  Software Engineering
# 1422  237540                   arthur      False  Software Engineering
# 496   245562                  Barbara      False  Software Engineering
# 524   257864              Yingxi Long      False          UX/UI Design
# 128   273010               Devon Chey      False                  None
# 110   273597               Emily Paul      False                  None
# 111   267184                Antonio P      False  Software Engineering
# 1369  239336                   Edmond      False  Software Engineering
# 864   242894              Elsa Rasmus      False          UX/UI Design
# 62    269103            Manon Morgaut      False                  None
# 1153  246230        Alexandre Schmitz      False  Software Engineering
# 117   266944                Charles R      False  Software Engineering
# 16    276085                  Stewart      False                  None
# 345   258027   Rafael Bueno Rodrigues      False  Software Engineering
# 541   261747  Ginevra Fontes Williams      False                  None
# 609   244149     Alejandro E. Marquez      False  Software Engineering
# 357   265498                Anonymous       True  Software Engineering
# 7     276315      Elizaveta Gorbunova      False                  None
# 36    256073           David Ferreira      False  Software Engineering
# 1297  243566   Alexandre-Olivier Nycz      False  Software Engineering
# 781   240988            Ian Izaguirre      False                  None
# 1789  240307         Jackson Graziano      False                  None
# 554   254462                 Kip Ladd      False     Digital Marketing
# 54    275286            Ruben Rubilar      False                  None
# 1020  233147          Karin Fernandez      False                  None
# 1128  246957           Inês Salgueiro      False  Software Engineering
# 816   245292                Anonymous       True          Data Science
# 802   245395           Carmen Preston      False          UX/UI Design
# 1364  244628      franklin de chanaud      False  Software Engineering
# 884   237055            Blake Bowland      False                  None
# 222   263100                Anonymous       True  Software Engineering
# 400   252937                Anonymous       True  Software Engineering
# 691   236567        Alexys Vanderford      False  Software Engineering
# 1877  239278                     Roel      False                  None
# 246   262719  Juan Carlos Vega Fosado      False  Software Engineering
# 1151  246476             Roan Mertens      False  Software Engineering
# 1532  241668        Damien Boussardon      False  Software Engineering
# 34    276059          Alexandra Vacca      False                  None
#
#       graduatingYear isAlumni                           jobTitle  \
# 476           2018.0     True                               None
# 125           2020.0    False
# 951           2016.0     True                               None
# 726           2018.0     True                               None
# 754           2018.0     True                               None
# 1             2021.0    False
# 16            2021.0     True
# 272           2020.0     True                               None
# 267           2020.0     True                               None
# 1129          2018.0     True                      Web developer
# 871           2019.0     True                               None
# 574           2018.0     True                               None
# 485           2018.0     True                           Web Dev.
# 1422          2018.0     True                         co-founder
# 496           2018.0     True                               None
# 524           2019.0    False                               None
# 128           2020.0    False                   Product Designer
# 110           2021.0    False                   Product Designer
# 111           2020.0    False                    Project Manager
# 1369          2018.0     True               Full-Stack Developer
# 864           2017.0     True                               None
# 62            2020.0    False
# 1153          2018.0     True  CXO and Co-Founder at Cerbo, Inc.
# 117           2020.0    False
# 16            2021.0    False
# 345           2019.0     True                               None
# 541           2019.0    False
# 609           2018.0     True                       Software Dev
# 357           2019.0    False
# 7             2021.0    False                       Data Analyst
# 36            2019.0     True                               None
# 1297          2018.0     True                               None
# 781           2017.0     True                               None
# 1789          2017.0     True                         Co-founder
# 554           2019.0     True                               None
# 54            2021.0    False
# 1020          2015.0     True                               None
# 1128          2018.0     True                               None
# 816           2018.0     True                               None
# 802           2018.0     True                               None
# 1364          2018.0     True                   Fullstack WebDev
# 884           2017.0     True                UX/Product Designer
# 222           2020.0    False                               None
# 400           2019.0     True                  Software Engineer
# 691           2018.0     True                            Web Dev
# 1877          2016.0     True                               None
# 246           2020.0    False                               None
# 1151          2018.0     True                               None
# 1532          2018.0     True           Full Stack Web Developer
# 34            2021.0    False        Sales and Marketing Manager
#
#                                                 tagline  \
# 476                              Amazing coding journey
# 125     A rigorous course but, ultimately, a great one.
# 951                               Worth What You Put In
# 726                                    Great experience
# 754                        Springboard UX Design Course
# 1                                       I learned a lot
# 16                                     Above and Beyond
# 272                         Awesome Learning Experience
# 267                      Overall pretty good experience
# 1129  Effective learning method, great overall expri...
# 871   If you want to be happy programming, choose Le...
# 574                                  Superb Institution
# 485                An experience that changes your life
# 1422                I recommend LeWagon to learn coding
# 496       A great experience that will change your life
# 524                      Wonderful course to UXUI world
# 128                                Excellent Experience
# 110                                    Believe the hype
# 111          The project based learning was a real plus
# 1369                           Le Wagon Tokyo batch#147
# 864                                         Springboard
# 62                    Intensive but definitely worth it
# 1153                           Life changing experience
# 117                   I highly recommend this program !
# 16                               App Academy Experience
# 345                           Be prepared to the market
# 541   Eye-opening experience and huge investment for...
# 609                                        Worthwhile.
# 357                     Change your life, learn to code
# 7                       Great and comprehensive program
# 36                                     Amazing Bootcamp
# 1297                             Change what YOU WORTH!
# 781                                          Just Do It
# 1789                    Change your life, learn to code
# 554   Good Way to get real-world experience in the l...
# 54                             Best decision in my life
# 1020                                 Highly recommended
# 1128                                      Love Le Wagon
# 816               Springboard Data Science Career Track
# 802                             Great UX Design Program
# 1364                  Le Wagon - incredible experience!
# 884                               Mentorship is the key
# 222                                            Positive
# 400                           My App Academy Experience
# 691                                   Web Dev Full-Time
# 1877                    “Le Wagon Amsterdam, Batch #38”
# 246                 Un gran Reto y una gran experiencia
# 1151                             An amazing experience!
# 1532                     Le wagon Bordeaux - Batch #127
# 34    Rake it until you make it! Changing Careers an...
#
#                                                    body  \
# 476   <span class="truncatable"><p>The Ironhack boot...
# 125   <span class="truncatable"><p>App Academy's cur...
# 951   <span class="truncatable"><p>App Academy is di...
# 726   <p>Everything is made to succeed, surrounded b...
# 754   <span class="truncatable"><p>I really enjoyed ...
# 1     <span class="truncatable"><p></p><p>I just gra...
# 16    <span class="truncatable"><p></p><p>very great...
# 272   <span class="truncatable"><p>Pros: <br>- You r...
# 267   <span class="truncatable"><p>Before attending,...
# 1129  <span class="truncatable"><p>I started my care...
# 871   <span class="truncatable"><p>Before the bootca...
# 574   <span class="truncatable"><p>I loved my time a...
# 485   <p>I am still amazing of all you can learn in ...
# 1422  <span class="truncatable"><p>My experience at ...
# 496   <span class="truncatable"><p>There are a lot o...
# 524   <span class="truncatable"><p></p><p>Springboar...
# 128   <span class="truncatable"><p></p><p>I had an a...
# 110   <span class="truncatable"><p></p><p>My experie...
# 111   <span class="truncatable"><p></p><p>As a proje...
# 1369  <span class="truncatable"><p>I have been livin...
# 864   <p>I thoroughly enjoyed the Springboard UX cla...
# 62    <span class="truncatable"><p>I decided to foll...
# 1153  <span class="truncatable"><p>As UX designer wh...
# 117   <span class="truncatable"><p>When I graduated ...
# 16    <span class="truncatable"><p></p><p>App Academ...
# 345   <span class="truncatable"><p>They make you be ...
# 541   <span class="truncatable"><p></p><p>I used to ...
# 609   <span class="truncatable"><p>You get what you ...
# 357   <p>I Joined Le Wagon in october in Batch #321 ...
# 7     <span class="truncatable"><p></p><p>I've enjoy...
# 36    <p>The bootcamp was an experience that prepare...
# 1297  <span class="truncatable"><p>When I was younge...
# 781   <span class="truncatable"><p>Before joining Ir...
# 1789  <span class="truncatable"><p>I attended Batch ...
# 554   <span class="truncatable"><p>I started out on ...
# 54    <span class="truncatable"><p></p><p>If you are...
# 1020  <span class="truncatable"><p>I had such a grea...
# 1128  <span class="truncatable"><p>In Le Wagon I’ve ...
# 816   <span class="truncatable"><p>This course reall...
# 802   <span class="truncatable"><p>I can only say gr...
# 1364  <span class="truncatable"><p>When I graduated ...
# 884   <span class="truncatable"><p>Springboard was a...
# 222   <p>I would recommend this course to anyone who...
# 400   <span class="truncatable"><p>If I had to, I wo...
# 691   <span class="truncatable"><p>I attended the Ir...
# 1877  <span class="truncatable"><p>*Background*
# <br>...
# 246   <span class="truncatable"><p>El asistir al Boo...
# 1151  <span class="truncatable"><p>If you are readin...
# 1532  <span class="truncatable"><p>Why Le Wagon?<br>...
# 34    <span class="truncatable"><p></p><p>I joined L...
#
#                                                 rawBody  ...   queryDate  \
# 476   The Ironhack bootcamp transformed me and my cl...  ...  2019-01-07
# 125   App Academy's curriculum is well designed and ...  ...  2020-07-24
# 951   App Academy is difficult. Extremely difficult....  ...  2017-01-23
# 726   Everything is made to succeed, surrounded by a...  ...  2018-03-16
# 754   I really enjoyed the way Springboard structure...  ...  2018-11-30
# 1     <p>I just graduated. The best part of the prog...  ...  2021-06-08
# 16    <p>very great course in web development .. goo...  ...  2021-03-13
# 272   Pros: \r\n- You really are able to create a fu...  ...  2020-02-04
# 267   Before attending, I had read reviews online th...  ...  2020-02-04
# 1129  I started my career in the shipping industry (...  ...  2019-02-16
# 871   Before the bootcamp, I studied in a school tha...  ...  2019-07-22
# 574   I loved my time at App Academy because it prov...  ...  2018-09-23
# 485   I am still amazing of all you can learn in onl...  ...  2018-12-07
# 1422  My experience at LeWagon was great in terms of...  ...  2018-07-13
# 496   There are a lot of pros to attending this boot...  ...  2018-11-06
# 524   <p>Springboard UX design is a thothought and c...  ...  2019-10-19
# 128   <p>I had an amazing experience with Springboar...  ...  2021-01-28
# 110   <p>My experience with Springboard has been tre...  ...  2021-02-12
# 111   <p>As a project manager in a start up, I wante...  ...  2020-08-05
# 1369  I have been living in Japan for 5 years workin...  ...  2018-08-16
# 864   I thoroughly enjoyed the Springboard UX class!...  ...  2018-03-12
# 62    I decided to follow Ironhack's program in the ...  ...  2020-10-05
# 1153  As UX designer who owns a startup in online ed...  ...  2019-01-17
# 117   When I graduated from my bachelor's degree in ...  ...  2020-07-30
# 16    <p>App Academy is one of the best bootcamp out...  ...  2021-04-19
# 345   They make you be prepared for the market. Thei...  ...  2019-10-23
# 541   <p>I used to work in an advertising agency as ...  ...  2020-02-07
# 609   You get what you put in. You have to study sup...  ...  2018-07-23
# 357   I Joined Le Wagon in october in Batch #321 and...  ...  2020-06-15
# 7     <p>I&#39;ve enjoyed my time at Yandex practicu...  ...  2021-04-23
# 36    The <Academia de Código_> bootcamp was an expe...  ...  2019-10-04
# 1297  When I was younger, I wanted to learn how to c...  ...  2018-10-01
# 781   Before joining Ironhack, I was apprehensive at...  ...  2017-12-21
# 1789  I attended Batch #64 in São Paulo.\r\n\r\nThe ...  ...  2017-07-12
# 554   I started out on the Digital Marketing Career ...  ...  2019-09-11
# 54    <p>If you are looking for a bootcamp in Tokyo,...  ...  2021-03-30
# 1020  I had such a great experience at Ironhack. The...  ...  2015-12-21
# 1128  In Le Wagon I’ve found myself in an exciting c...  ...  2019-02-20
# 816   This course really built my confidence in prep...  ...  2018-08-16
# 802   I can only say great things about Springboard ...  ...  2018-10-26
# 1364  When I graduated from an agronomy school, I wa...  ...  2018-08-18
# 884   Springboard was a fantastic course with a mult...  ...  2017-08-08
# 222   I would recommend this course to anyone who is...  ...  2020-03-30
# 400   If I had to, I would join App Academy again. I...  ...  2019-07-29
# 691   I attended the IronHack Web Development full t...  ...  2018-04-05
# 1877  *Background*
# \r\nAs a graduate in Entrepreneur...  ...  2017-01-10
# 246   El asistir al Bootcamp de Ironhack, fue mucho ...  ...  2020-03-12
# 1151  If you are reading this review it means that y...  ...  2019-01-19
# 1532  Why Le Wagon?\r\n        \r\n  I've always bee...  ...  2018-04-12
# 34    <p>I joined Le Wagon with a view to change my ...  ...  2021-04-19
#
#                                   program             user overallScore  \
# 476   Full-time Web Development Bootcamp   {'image': None}          5.0
# 125    Software Engineer Track: In-Person  {'image': None}          4.7
# 951    Software Engineer Track: In-Person  {'image': None}          5.0
# 726   Full-time Web Development Bootcamp   {'image': None}          5.0
# 754                             UX Design  {'image': None}          3.7
# 1               UI/UX Design Career Track  {'image': None}          4.7
# 16                          Web Developer  {'image': None}          5.0
# 272    Software Engineer Track: In-Person  {'image': None}          5.0
# 267    Software Engineer Track: In-Person  {'image': None}          4.0
# 1129    FullStack program - 35+ locations  {'image': None}          4.7
# 871     FullStack program - 35+ locations  {'image': None}          5.0
# 574    Software Engineer Track: In-Person  {'image': None}          4.7
# 485   Full-time Web Development Bootcamp   {'image': None}          5.0
# 1422    FullStack program - 35+ locations  {'image': None}          4.7
# 496   Full-time Web Development Bootcamp   {'image': None}          5.0
# 524                                        {'image': None}          4.7
# 128             UI/UX Design Career Track  {'image': None}          5.0
# 110                       UX Career Track  {'image': None}          5.0
# 111                                        {'image': None}          5.0
# 1369    FullStack program - 35+ locations  {'image': None}          5.0
# 864                             UX Design  {'image': None}          5.0
# 62               Web Development Bootcamp  {'image': None}          5.0
# 1153    FullStack program - 35+ locations  {'image': None}          5.0
# 117                                        {'image': None}          5.0
# 16     Software Engineer Track: In-Person  {'image': None}          5.0
# 345             Part-time Web Development  {'image': None}          5.0
# 541                                        {'image': None}          5.0
# 609    Software Engineer Track: In-Person  {'image': None}          5.0
# 357    Web Development Course - Full-Time  {'image': None}          5.0
# 7                            Data Analyst  {'image': None}          5.0
# 36                                   None  {'image': None}          5.0
# 1297    FullStack program - 35+ locations  {'image': None}          5.0
# 781   Full-time Web Development Bootcamp   {'image': None}          5.0
# 1789    FullStack program - 35+ locations  {'image': None}          5.0
# 554                                  None  {'image': None}          5.0
# 54     Web Development Course - Full-Time  {'image': None}          5.0
# 1020            Part-time Web Development  {'image': None}          5.0
# 1128    FullStack program - 35+ locations  {'image': None}          5.0
# 816             Data Science Career Track  {'image': None}          4.7
# 802                             UX Design  {'image': None}          5.0
# 1364    FullStack program - 35+ locations  {'image': None}          5.0
# 884                             UX Design  {'image': None}          4.7
# 222    Software Engineer Track: In-Person  {'image': None}          4.0
# 400    Software Engineer Track: In-Person  {'image': None}          4.0
# 691   Full-time Web Development Bootcamp   {'image': None}          5.0
# 1877    FullStack program - 35+ locations  {'image': None}          5.0
# 246              Web Development Bootcamp  {'image': None}          5.0
# 1151    FullStack program - 35+ locations  {'image': None}          5.0
# 1532    FullStack program - 35+ locations  {'image': None}          5.0
# 34     Web Development Course - Full-Time  {'image': None}          4.7
#
#      comments overall curriculum jobSupport  \
# 476        []     5.0        5.0        5.0
# 125        []     5.0        4.0        5.0
# 951        []     5.0        5.0        5.0
# 726        []     5.0        5.0        5.0
# 754        []     4.0        3.0        4.0
# 1          []     5.0        5.0        4.0
# 16         []     5.0        5.0        5.0
# 272        []     5.0        5.0        5.0
# 267        []     4.0        4.0        4.0
# 1129       []     5.0        5.0        4.0
# 871        []     5.0        5.0        5.0
# 574        []     5.0        5.0        4.0
# 485        []     5.0        5.0        5.0
# 1422       []     5.0        5.0        4.0
# 496        []     5.0        5.0        5.0
# 524        []     5.0        5.0        4.0
# 128        []     5.0        5.0        5.0
# 110        []     5.0        5.0        5.0
# 111        []     5.0        5.0        5.0
# 1369       []     5.0        5.0        5.0
# 864        []     5.0        5.0        5.0
# 62         []     5.0        5.0        NaN
# 1153       []     5.0        5.0        5.0
# 117        []     5.0        5.0        5.0
# 16         []     5.0        5.0        5.0
# 345        []     5.0        5.0        5.0
# 541        []     5.0        5.0        5.0
# 609        []     5.0        5.0        5.0
# 357        []     5.0        5.0        5.0
# 7          []     5.0        5.0        5.0
# 36         []     5.0        5.0        5.0
# 1297       []     5.0        5.0        5.0
# 781        []     5.0        5.0        5.0
# 1789       []     5.0        5.0        5.0
# 554        []     5.0        5.0        5.0
# 54         []     5.0        5.0        5.0
# 1020       []     5.0        NaN        NaN
# 1128       []     5.0        5.0        5.0
# 816        []     5.0        4.0        5.0
# 802        []     5.0        5.0        5.0
# 1364       []     5.0        5.0        5.0
# 884        []     5.0        5.0        4.0
# 222        []     4.0        4.0        4.0
# 400        []     4.0        4.0        4.0
# 691        []     5.0        5.0        5.0
# 1877       []     5.0        5.0        5.0
# 246        []     5.0        5.0        5.0
# 1151       []     5.0        5.0        5.0
# 1532       []     5.0        5.0        5.0
# 34         []     5.0        5.0        4.0
#
#                                             review_body               school
# 476   The Ironhack bootcamp transformed me and my cl...             ironhack
# 125   App Academy's curriculum is well designed and ...          app-academy
# 951   App Academy is difficult. Extremely difficult....          app-academy
# 726   Everything is made to succeed, surrounded by a...             ironhack
# 754   I really enjoyed the way Springboard structure...          springboard
# 1     I just graduated. The best part of the program...          springboard
# 16    very great course in web development .. good r...  practicum-by-yandex
# 272   Pros: - You really are able to create a fully ...          app-academy
# 267   Before attending, I had read reviews online th...          app-academy
# 1129  I started my career in the shipping industry (...             le-wagon
# 871   Before the bootcamp, I studied in a school tha...             le-wagon
# 574   I loved my time at App Academy because it prov...          app-academy
# 485   I am still amazing of all you can learn in onl...             ironhack
# 1422  My experience at LeWagon was great in terms of...             le-wagon
# 496   There are a lot of pros to attending this boot...             ironhack
# 524   Springboard UX design is a thothought and comp...          springboard
# 128   I had an amazing experience with Springboard! ...          springboard
# 110   My experience with Springboard has been tremen...          springboard
# 111   As a project manager in a start up, I wanted t...           la-capsule
# 1369  I have been living in Japan for 5 years workin...             le-wagon
# 864   I thoroughly enjoyed the Springboard UX class!...          springboard
# 62    I decided to follow Ironhack's program in the ...             ironhack
# 1153  As UX designer who owns a startup in online ed...             le-wagon
# 117   When I graduated from my bachelor's degree in ...           la-capsule
# 16    App Academy is one of the best bootcamp out he...          app-academy
# 345   They make you be prepared for the market. Thei...             ironhack
# 541   I used to work in an advertising agency as a J...             le-wagon
# 609   You get what you put in. You have to study sup...          app-academy
# 357   I Joined Le Wagon in october in Batch #321 and...             le-wagon
# 7     I've enjoyed my time at Yandex practicum. The ...  practicum-by-yandex
# 36    The bootcamp was an experience that prepared m...   academia-de-codigo
# 1297  When I was younger, I wanted to learn how to c...             le-wagon
# 781   Before joining Ironhack, I was apprehensive at...             ironhack
# 1789  I attended Batch #64 in São Paulo.The "change ...             le-wagon
# 554   I started out on the Digital Marketing Career ...          springboard
# 54    If you are looking for a bootcamp in Tokyo, th...             le-wagon
# 1020  I had such a great experience at Ironhack. The...             ironhack
# 1128  In Le Wagon I’ve found myself in an exciting c...             le-wagon
# 816   This course really built my confidence in prep...          springboard
# 802   I can only say great things about Springboard ...          springboard
# 1364  When I graduated from an agronomy school, I wa...             le-wagon
# 884   Springboard was a fantastic course with a mult...          springboard
# 222   I would recommend this course to anyone who is...          app-academy
# 400   If I had to, I would join App Academy again. I...          app-academy
# 691   I attended the IronHack Web Development full t...             ironhack
# 1877  *Background*
# As a graduate in Entrepreneurship...             le-wagon
# 246   El asistir al Bootcamp de Ironhack, fue mucho ...             ironhack
# 1151  If you are reading this review it means that y...             le-wagon
# 1532  Why Le Wagon?  I've always been interested by ...             le-wagon
# 34    I joined Le Wagon with a view to change my car...             le-wagon
#
# [50 rows x 21 columns]

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# <ipython-input-5-7111c633f1e2>:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# la-capsule
# app-academy
# springboard
# metis
# practicum-by-yandex
# le-wagon
# academia-de-codigo
# react-graphql-academy

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id        description  country.id country.name country.abbrev  city.id  \
#  0  15863      Paris, France          38       France             FR    31136
#  1  17050       Lyon, France          38       France             FR    31106
#  2  17450  Marseille, France          38       France             FR    31129
#
#     city.name city.keyword      school  school_id
#  0      Paris        paris  la-capsule      10853
#  1       Lyon         lyon  la-capsule      10853
#  2  Marseille    marseille  la-capsule      10853  ,
#        id                       description  country.id   country.name  \
#  0  15704  San Francisco, CA, United States         1.0  United States
#  1  15705  New York City, NY, United States         1.0  United States
#  2  15862                            Online         NaN            NaN
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US         6  California           CA    california     13.0
#  1             US        34    New York           NY      new-york   1507.0
#  2            NaN         1      Online       Online        online      NaN
#
#         city.name   city.keyword       school  school_id
#  0  San Francisco  san-francisco  app-academy      10525
#  1            NYC  new-york-city  app-academy      10525
#  2            NaN            NaN  app-academy      10525  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ,
#        id           description  country.id   country.name country.abbrev  \
#  0  15718     New York City, NY         1.0  United States             US
#  1  16079     San Francisco, CA         1.0  United States             US
#  2  16081                Online         NaN            NaN            NaN
#  3  16263           Chicago, IL         1.0  United States             US
#  4  16278           Seattle, WA         1.0  United States             US
#  5  16803  Singapore, Singapore        56.0      Singapore             SG
#
#     state.id  state.name state.abbrev state.keyword  city.id      city.name  \
#  0      34.0    New York           NY      new-york   1507.0            NYC
#  1       6.0  California           CA    california     13.0  San Francisco
#  2       1.0      Online       Online        online      NaN            NaN
#  3      15.0    Illinois           IL      illinois     39.0        Chicago
#  4      49.0  Washington           WA    washington     97.0        Seattle
#  5       NaN         NaN          NaN           NaN  31154.0      Singapore
#
#      city.keyword school  school_id
#  0  new-york-city  metis      10886
#  1  san-francisco  metis      10886
#  2            NaN  metis      10886
#  3        chicago  metis      10886
#  4        seattle  metis      10886
#  5      singapore  metis      10886  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  17154      Online         1     Online       Online        online
#
#                  school  school_id
#  0  practicum-by-yandex      11225  ,
#         id                  description  country.id          country.name  \
#  0   15803         Melbourne, Australia          20             Australia
#  1   15904          Casablanca, Morocco          44               Morocco
#  2   15906      Buenos Aires, Argentina          60             Argentina
#  3   15964            Brussels, Belgium          46               Belgium
#  4   15979                 Milan, Italy          39                 Italy
#  5   15996               Chengdu, China          15                 China
#  6   16039          Mexico City, Mexico          29                Mexico
#  7   16049       Amsterdam, Netherlands          59           Netherlands
#  8   16106            Sao Paulo, Brazil          42                Brazil
#  9   16124             Barcelona, Spain          12                 Spain
#  10  16145             Bordeaux, France          38                France
#  11  16146          Copenhagen, Denmark          47               Denmark
#  12  16147                Lille, France          38                France
#  13  16148             Lisbon, Portugal          28              Portugal
#  14  16149              Bali, Indonesia          35             Indonesia
#  15  16150               Nantes, France          38                France
#  16  16274      Rio de Janeiro , Brazil          42                Brazil
#  17  16275            Marseille, France          38                France
#  18  16282             Montreal, Canada           2                Canada
#  19  16283              Shanghai, China          15                 China
#  20  16307       Belo Horizonte, Brazil          42                Brazil
#  21  16407                 Tokyo, Japan          48                 Japan
#  22  16408                 Lyon, France          38                France
#  23  16478             Tel Aviv, Israel           5                Israel
#  24  16570                 Kyoto, Japan          48                 Japan
#  25  16765              Berlin, Germany          57               Germany
#  26  16767                Paris, France          38                France
#  27  16775              Shenzhen, China          15                 China
#  28  16776        Lausanne, Switzerland          32           Switzerland
#  29  16800                Madrid, Spain          12                 Spain
#  30  16804                 Oslo, Norway          52                Norway
#  31  16805               Rennes, France          38                France
#  32  16936         Singapore, Singapore          56             Singapore
#  33  16967              London, England          61               England
#  34  16968                  Rome, Italy          39                 Italy
#  35  17128            Stockholm, Sweden          37                Sweden
#  36  17129                 Seoul, Korea          55           South Korea
#  37  17157             Istanbul, Turkey         237                Turkey
#  38  17188              Toronto, Canada           2                Canada
#  39  17314  Dubai, United Arab Emirates          34  United Arab Emirates
#  40  17395              Munich, Germany          57               Germany
#  41  17476              Santiago, Chile          22                 Chile
#  42  17732       Saint Pierre, Mauritus         171             Mauritius
#  43  17765                 Nice, France          38                France
#  44  17772             Cologne, Germany          57               Germany
#  45  17835                   Lima, Peru         196                  Peru
#
#     country.abbrev  city.id        city.name    city.keyword    school  \
#  0              AU    31174        Melbourne       melbourne  le-wagon
#  1              MA    31119       Casablanca      casablanca  le-wagon
#  2              AR    31171     Buenos Aires    buenos-aires  le-wagon
#  3              BE    31125         Brussels        brussels  le-wagon
#  4              IT    31107            Milan           milan  le-wagon
#  5              CN    31126          Chengdu         chengdu  le-wagon
#  6              MX    31175      Mexico City     mexico-city  le-wagon
#  7              NL    31168        Amsterdam       amsterdam  le-wagon
#  8              BR    31121        Sao Paulo       sao-paulo  le-wagon
#  9              ES    31170        Barcelona       barcelona  le-wagon
#  10             FR    31124         Bordeaux        bordeaux  le-wagon
#  11             DK    31127       Copenhagen      copenhagen  le-wagon
#  12             FR    31128            Lille           lille  le-wagon
#  13             PT    31075           Lisbon          lisbon  le-wagon
#  14             ID    31169             Bali            bali  le-wagon
#  15             FR    31130           Nantes          nantes  le-wagon
#  16             BR    31131  Rio de Janeiro   rio-de-janeiro  le-wagon
#  17             FR    31129        Marseille       marseille  le-wagon
#  18             CA    31135         Montreal        montreal  le-wagon
#  19             CN    31108         Shanghai        shanghai  le-wagon
#  20             BR    31123   Belo Horizonte  belo-horizonte  le-wagon
#  21             JP    31132            Tokyo           tokyo  le-wagon
#  22             FR    31106             Lyon            lyon  le-wagon
#  23             IL    31079         Tel Aviv        tel-aviv  le-wagon
#  24             JP    31134            Kyoto           kyoto  le-wagon
#  25             DE    31156           Berlin          berlin  le-wagon
#  26             FR    31136            Paris           paris  le-wagon
#  27             CN    31164         Shenzhen        shenzhen  le-wagon
#  28             CH    31163         Lausanne        lausanne  le-wagon
#  29             ES    31052           Madrid          madrid  le-wagon
#  30             NO    31145             Oslo            oslo  le-wagon
#  31             FR    31147           Rennes          rennes  le-wagon
#  32             SG    31154        Singapore       singapore  le-wagon
#  33             GB    31176           London          london  le-wagon
#  34             IT    31180             Rome            rome  le-wagon
#  35             SE    31109        Stockholm       stockholm  le-wagon
#  36             KR    31151            Seoul            seol  le-wagon
#  37             TR    31193         Istanbul        istanbul  le-wagon
#  38             CA    31152          Toronto         toronto  le-wagon
#  39             AE    31093            Dubai           dubai  le-wagon
#  40             DE    31158           Munich          munich  le-wagon
#  41             CL    31067         Santiago        santiago  le-wagon
#  42             MU    31246     Saint Pierre    saint-pierre  le-wagon
#  43             FR    31239             Nice            nice  le-wagon
#  44             DE    31254          Cologne         cologne  le-wagon
#  45             PE    31256             Lima            lima  le-wagon
#
#      school_id
#  0       10868
#  1       10868
#  2       10868
#  3       10868
#  4       10868
#  5       10868
#  6       10868
#  7       10868
#  8       10868
#  9       10868
#  10      10868
#  11      10868
#  12      10868
#  13      10868
#  14      10868
#  15      10868
#  16      10868
#  17      10868
#  18      10868
#  19      10868
#  20      10868
#  21      10868
#  22      10868
#  23      10868
#  24      10868
#  25      10868
#  26      10868
#  27      10868
#  28      10868
#  29      10868
#  30      10868
#  31      10868
#  32      10868
#  33      10868
#  34      10868
#  35      10868
#  36      10868
#  37      10868
#  38      10868
#  39      10868
#  40      10868
#  41      10868
#  42      10868
#  43      10868
#  44      10868
#  45      10868  ,
#        id                description  country.id country.name country.abbrev  \
#  0  16627           Lisbon, Portugal          28     Portugal             PT
#  1  16771            Porto, Portugal          28     Portugal             PT
#  2  16798  Terceira Island, Portugal          28     Portugal             PT
#  3  16801           Fundao, Portugal          28     Portugal             PT
#
#     city.id        city.name     city.keyword              school  school_id
#  0    31075           Lisbon           lisbon  academia-de-codigo      10494
#  1    31102            Porto            porto  academia-de-codigo      10494
#  2    31161  Terceira Island  terceira-island  academia-de-codigo      10494
#  3    31140           Fundao           fundao  academia-de-codigo      10494  ,
#        id             description  country.id    country.name country.abbrev  \
#  0  15748         London, England        11.0  United Kingdom             GB
#  1  16749        Lisbon, Portugal        28.0        Portugal             PT
#  2  17023  Amsterdam, Netherlands        59.0     Netherlands             NL
#  3  17242                  Online         NaN             NaN            NaN
#  4  17251         Berlin, Germany        57.0         Germany             DE
#  5  17252        Barcelona, Spain        12.0           Spain             ES
#
#     city.id  city.name city.keyword  state.id state.name state.abbrev  \
#  0  31176.0     London       london       NaN        NaN          NaN
#  1  31075.0     Lisbon       lisbon       NaN        NaN          NaN
#  2  31168.0  Amsterdam    amsterdam       NaN        NaN          NaN
#  3      NaN        NaN          NaN       1.0     Online       Online
#  4  31156.0     Berlin       berlin       NaN        NaN          NaN
#  5  31170.0  Barcelona    barcelona       NaN        NaN          NaN
#
#    state.keyword                 school  school_id
#  0           NaN  react-graphql-academy      10972
#  1           NaN  react-graphql-academy      10972
#  2           NaN  react-graphql-academy      10972
#  3        online  react-graphql-academy      10972
#  4           NaN  react-graphql-academy      10972
#  5           NaN  react-graphql-academy      10972  ]

# %%
locations = pd.concat(locations_list)

# %%
courses = pd.concat(courses_list)
courses.head(10)
# Out:
#                               courses       school  school_id
# 0             Cyber Security Bootcamp     ironhack      10828
# 1             Cybersecurity Part-Time     ironhack      10828
# 2             Data Analytics Bootcamp     ironhack      10828
# 3            Data Analytics Part-Time     ironhack      10828
# 4               UX/UI Design Bootcamp     ironhack      10828
# 5              UX/UI Design Part-Time     ironhack      10828
# 6            Web Development Bootcamp     ironhack      10828
# 7           Web Development Part-Time     ironhack      10828
# 0  Fullstack JavaScript Web Developer   la-capsule      10853
# 0                       Bootcamp Prep  app-academy      10525

# %%
badges_raw = pd.concat(badges_list)
badges_raw = badges_raw.drop_duplicates(subset=['name'])
badges_raw
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 2             <p>School guarantees job placement</p>  app-academy      10525

# %%
# superstore.insert(0,'Profitable?',(superstore['Profit'].apply(profitable)))

def badges_m(row):
    if row == 'Available Online':
        return 1
    elif row == 'Verified Outcomes':
        return 2
    elif row == 'Flexible Classes':
        return 3
    elif row == 'Job Guarantee':
        return 4

# %%
badges_raw.insert(0,'badges_id',(badges_raw['name'].apply(badges_m)))

# %%
badges = badges_raw

# %%
badges
# Out:
#    badges_id               name            keyword  \
# 0          1   Available Online   available_online
# 1          2  Verified Outcomes  verified_outcomes
# 2          3   Flexible Classes   flexible_classes
# 2          4      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 2             <p>School guarantees job placement</p>  app-academy      10525

# %%
badges.columns = ['badges_id','name','keyword','description','school','school_id']

# %%
badges
# Out:
#    badges_id               name            keyword  \
# 0          1   Available Online   available_online
# 1          2  Verified Outcomes  verified_outcomes
# 2          3   Flexible Classes   flexible_classes
# 2          4      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 2             <p>School guarantees job placement</p>  app-academy      10525

# %%
clean_badges = badges[['badges_id','name']]

# %%
clean_badges = clean_badges.drop_duplicates(subset=['badges_id'])

# %%
display(clean_badges)
# Out:
#    badges_id               name
# 0          1   Available Online
# 1          2  Verified Outcomes
# 2          3   Flexible Classes
# 2          4      Job Guarantee

# %%
clean_schools = badges[['school_id','school']]
clean_schools.columns = ['schools_id','name']
clean_schools = clean_schools.drop_duplicates(subset=['schools_id'])

# %%
clean_schools
# Out:
#    schools_id         name
# 0       10828     ironhack
# 2       10525  app-academy

# %%
schools
# Out:
# {'ironhack': 10828,
#  'la-capsule': 10853,
#  'app-academy': 10525,
#  'springboard': 11035,
#  'metis': 10886,
#  'practicum-by-yandex': 11225,
#  'le-wagon': 10868,
#  'academia-de-codigo': 10494,
#  'react-graphql-academy': 10972}

# %%
clean_badges_schools = badges.drop_duplicates(subset=['name','badges_id'])
clean_badges_schools = clean_badges_schools[['badges_id','school_id']]
clean_badges_schools.insert(0,'school_badges_id',(range(1,5)))
clean_badges_schools
# Out:
#    school_badges_id  badges_id  school_id
# 0                 1          1      10828
# 1                 2          2      10828
# 2                 3          3      10828
# 2                 4          4      10525

# %%
clean_comments = comments.merge(schools, how='inner', on='school')
to_drop = ['graduatingYear','tagline','body','rawBody','user','comments','review_body','anonymous','createdAt','jobTitle','hostProgramName','queryDate']
clean_comments.drop(to_drop,inplace=True,axis=1,)
clean_comments.drop(['website','description','LogoUrl','school'], inplace=True,axis=1)
clean_comments = clean_comments.fillna(0)
clean_comments['overall'] = clean_comments['overall'].apply(lambda x : float(x))
clean_comments['overallScore'] = clean_comments['overallScore'].apply(lambda x : float(x))
clean_comments['curriculum'] = clean_comments['curriculum'].apply(lambda x : float(x))
clean_comments['jobSupport'] = clean_comments['jobSupport'].apply(lambda x : float(x))

clean_comments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-63a28a4d9e0c> in <module>
# ----> 1 clean_comments = comments.merge(schools, how='inner', on='school')
#       2 to_drop = ['graduatingYear','tagline','body','rawBody','user','comments','review_body','anonymous','createdAt','jobTitle','hostProgramName','queryDate']
#       3 clean_comments.drop(to_drop,inplace=True,axis=1,)
#       4 clean_comments.drop(['website','description','LogoUrl','school'], inplace=True,axis=1)
#       5 clean_comments = clean_comments.fillna(0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     592     ):
#     593         _left = _validate_operand(left)
# --> 594         _right = _validate_operand(right)
#     595         self.left = self.orig_left = _left
#     596         self.right = self.orig_right = _right
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_operand(obj)
#    2059             return obj.to_frame()
#    2060     else:
# -> 2061         raise TypeError(
#    2062             f"Can only merge Series or DataFrame objects, a {type(obj)} was passed"
#    2063         )
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'dict'> was passed

# %%
locations_clean = locations.copy()
to_drop = ['description','country.id','country.abbrev','city.id','city.keyword','state.id','state.name','state.abbrev','state.keyword']
locations_clean.drop(to_drop,inplace=True,axis=1,)
locations_clean.rename(columns = {'id':'location_id','country.name':'country','city.name':'city'}, inplace = True)

# %%
clean_locations = locations_clean
clean_locations = clean_locations.fillna('Online')

# %%
clean_locations

# %%
display(clean_schools)
display(clean_badges)
display(clean_badges_schools)
display(clean_comments)
display(clean_locations)

# %%
#################CREATING A CONNECTION TO THE DATABASE#####################
import pymysql
import getpass
import mysql.connector
from sqlalchemy import create_engine

# Connect to the database

host="database-1.cesj3b2ko52z.us-east-2.rds.amazonaws.com"
port=3306
dbname="project"
user="root"
password="12345678"


#engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
#                       .format(user="root",
#                               pw="1234",
#                               db="project"))

engine = create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'
            .format(user, password,host, dbname)).connect()


# create cursor

# %%
clean_comments.to_sql('comments', con = engine,if_exists = 'replace')

# %%
clean_schools.to_sql('schools', con = engine,if_exists = 'replace')

# %%
clean_badges.to_sql('badges', con = engine,if_exists = 'replace')

# %%
clean_badges_schools.to_sql('school_badges_id', con = engine,if_exists = 'replace')

# %%
clean_locations.to_sql('locations', con = engine,if_exists = 'replace')

# %%
query = pd.read_sql_query("""SELECT * FROM comments;""", engine)

# %%
query
# Out:
#       index      id                     name  isAlumni  \
# 0         0  276568  Guilherme golabek brein         0
# 1         1  276147          Charlotte Urvoy         0
# 2         2  275972                Anonymous         0
# 3         3  275872             Ahmad Khalaf         0
# 4         4  275855        Morgane Favchtein         0
# ...     ...     ...                      ...       ...
# 3017   3017  234894             Stephanie S.         1
# 3018   3018  234877                 Joe Fang         1
# 3019   3019  234838                    Zeina         1
# 3020   3020  242681                     Jean         1
# 3021   3021  234178                      Ben         1
#
#                         program  overallScore  overall  curriculum  \
# 0     Web Development Part-Time           1.0      1.0         1.0
# 1         UX/UI Design Bootcamp           5.0      5.0         5.0
# 2         UX/UI Design Bootcamp           4.0      5.0         4.0
# 3         UX/UI Design Bootcamp           4.0      4.0         4.0
# 4         UX/UI Design Bootcamp           4.3      5.0         4.0
# ...                         ...           ...      ...         ...
# 3017                  UX Design           5.0      5.0         5.0
# 3018                  UX Design           5.0      5.0         5.0
# 3019                  UX Design           3.7      4.0         4.0
# 3020                  UX Design           5.0      5.0         5.0
# 3021                  UX Design           4.7      5.0         5.0
#
#       jobSupport  school_id
# 0            1.0      10828
# 1            5.0      10828
# 2            3.0      10828
# 3            4.0      10828
# 4            4.0      10828
# ...          ...        ...
# 3017         5.0      11035
# 3018         5.0      11035
# 3019         3.0      11035
# 3020         5.0      11035
# 3021         4.0      11035
#
# [3022 rows x 10 columns]
