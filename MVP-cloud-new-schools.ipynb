# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'la-capsule' : 10853,
'app-academy' : 10525,
'springboard' : 11035,
'metis' : 10886,
'practicum-by-yandex' : 11225,
'le-wagon' : 10868,
'academia-de-codigo' :10494 ,
'react-graphql-academy' : 10972
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
get_comments_school("ironhack")
# Out:
#           id                     name  anonymous hostProgramName  \
# 0     276568  Guilherme golabek brein      False            None
# 1     276147          Charlotte Urvoy      False            None
# 2     275972                Anonymous       True            None
# 3     275872             Ahmad Khalaf      False            None
# 4     275855        Morgane Favchtein      False            None
# ...      ...                      ...        ...             ...
# 1040  231772                Anonymous      False            None
# 1041  231636          Marcos Sorribas      False            None
# 1042  231611            Xabier Vicuña      False            None
# 1043  231609                      JHD      False            None
# 1044  231815    Enrique Isasi Velasco      False    UX/UI Design
#
#       graduatingYear  isAlumni                                 jobTitle  \
# 0               2018     False                         Senior Associate
# 1               2021     False                           UX UI Designer
# 2               2021     False
# 3               2021     False                         Product Designer
# 4               2021     False                           UX UI Designer
# ...              ...       ...                                      ...
# 1040            2014      True                                     None
# 1041            2014      True                            iOS Developer
# 1042            2014      True                             Entrepreneur
# 1043            2014      True                                     None
# 1044            2014      True  Founder, RoR Developer @ Decorissimo.es
#
#                                                 tagline  \
# 0                                      Improper billing
# 1                                  Riche et pragmatique
# 2                                    Amazing experience
# 3                           Intense but good experience
# 4                                Very nice experience !
# ...                                                 ...
# 1040  Learn in two months what would otherwise take ...
# 1041  El mejor bootcamp al que he asistido. Una expe...
# 1042            Great experience, I highly recommend it
# 1043                      It was an amazing experience!
# 1044                                   Simply gorgeous.
#
#                                                    body  \
# 0     <span class="truncatable"><p></p><p>A year aft...
# 1     <span class="truncatable"><p></p><p>- La métho...
# 2     <span class="truncatable"><p></p><p>the UX/UI ...
# 3     <span class="truncatable"><p></p><p>When I sta...
# 4     <span class="truncatable"><p></p><p>The UX UI ...
# ...                                                 ...
# 1040  <span class="truncatable"><p>I can fully recom...
# 1041  <span class="truncatable"><p>Asistí al primer ...
# 1042  <span class="truncatable"><p>Excellent product...
# 1043  <span class="truncatable"><p>I was part of the...
# 1044  <span class="truncatable"><p>I attended the Ir...
#
#                                                 rawBody  ...   queryDate  \
# 0     <p>A year after completing my course, ironhack...  ...  2021-04-30
# 1     <p>- La m&eacute;thode d&#39;apprentissage est...  ...  2021-04-20
# 2     <p>the UX/UI bootcamp has been an amazing lear...  ...  2021-04-17
# 3     <p>When I started I was a little disappointed ...  ...  2021-04-15
# 4     <p>The UX UI Design bootcamp is a great way to...  ...  2021-04-14
# ...                                                 ...  ...         ...
# 1040  I can fully recommend IronHack for any of you ...  ...  2014-09-30
# 1041  Asistí al primer bootcamp de desarrollo de iOS...  ...  2014-09-24
# 1042  Excellent product. Great experience. Worth eve...  ...  2014-09-24
# 1043  I was part of the first English run of Ironhac...  ...  2014-09-24
# 1044  I attended the Ironhack Madrid Bootcamp on Jan...  ...  2014-09-23
#
#                                   program             user overallScore  \
# 0               Web Development Part-Time  {'image': None}          1.0
# 1                   UX/UI Design Bootcamp  {'image': None}          5.0
# 2                   UX/UI Design Bootcamp  {'image': None}          4.0
# 3                   UX/UI Design Bootcamp  {'image': None}          4.0
# 4                   UX/UI Design Bootcamp  {'image': None}          4.3
# ...                                   ...              ...          ...
# 1040            Part-time Web Development  {'image': None}          5.0
# 1041  Full-time Web Development Bootcamp   {'image': None}          5.0
# 1042            Part-time Web Development  {'image': None}          5.0
# 1043            Part-time Web Development  {'image': None}          5.0
# 1044            Part-time Web Development  {'image': None}          5.0
#
#      comments overall curriculum jobSupport  \
# 0          []     1.0        1.0        1.0
# 1          []     5.0        5.0        5.0
# 2          []     5.0        4.0        3.0
# 3          []     4.0        4.0        4.0
# 4          []     5.0        4.0        4.0
# ...       ...     ...        ...        ...
# 1040       []     5.0        5.0        5.0
# 1041       []     5.0        5.0        5.0
# 1042       []     5.0        5.0        5.0
# 1043       []     5.0        5.0        5.0
# 1044       []     5.0        5.0        5.0
#
#                                             review_body    school
# 0     A year after completing my course, ironhack co...  ironhack
# 1     - La méthode d'apprentissage est l'une des mei...  ironhack
# 2     the UX/UI bootcamp has been an amazing learnin...  ironhack
# 3     When I started I was a little disappointed but...  ironhack
# 4     The UX UI Design bootcamp is a great way to tr...  ironhack
# ...                                                 ...       ...
# 1040  I can fully recommend IronHack for any of you ...  ironhack
# 1041  Asistí al primer bootcamp de desarrollo de iOS...  ironhack
# 1042  Excellent product. Great experience. Worth eve...  ironhack
# 1043  I was part of the first English run of Ironhac...  ironhack
# 1044  I attended the Ironhack Madrid Bootcamp on Jan...  ironhack
#
# [1045 rows x 21 columns]

# %%
# could you write this as a list comprehension? ;)
# comments = []

# for school in schools.keys():
#    print(school)
#    comments.append(get_comments_school(school))
    
comments = [get_comments_school(key) for key in schools.keys()]

comments = pd.concat(comments)
comments
# Out:
#          id                     name  anonymous hostProgramName  \
# 0    276568  Guilherme golabek brein      False            None
# 1    276147          Charlotte Urvoy      False            None
# 2    275972                Anonymous       True            None
# 3    275872             Ahmad Khalaf      False            None
# 4    275855        Morgane Favchtein      False            None
# ..      ...                      ...        ...             ...
# 918  234894             Stephanie S.      False            None
# 919  234877                 Joe Fang      False            None
# 920  234838                    Zeina      False            None
# 921  242681                     Jean      False            None
# 922  234178                      Ben      False            None
#
#      graduatingYear  isAlumni                         jobTitle  \
# 0            2018.0     False                 Senior Associate
# 1            2021.0     False                   UX UI Designer
# 2            2021.0     False
# 3            2021.0     False                 Product Designer
# 4            2021.0     False                   UX UI Designer
# ..              ...       ...                              ...
# 918          2015.0      True          Website Manager-UX Lead
# 919          2015.0      True                      UX Designer
# 920          2016.0      True          Senior Graphic Designer
# 921          2016.0      True  Lead Designer/Creative Director
# 922          2016.0      True                             None
#
#                                                tagline  \
# 0                                     Improper billing
# 1                                 Riche et pragmatique
# 2                                   Amazing experience
# 3                          Intense but good experience
# 4                               Very nice experience !
# ..                                                 ...
# 918              Excellent and comprehensive UX course
# 919        Springboard helped me start my career in UX
# 920                                 Highly recommended
# 921    A way to stay current for the highly motivated!
# 922  Springboard is an excellent course for self dr...
#
#                                                   body  \
# 0    <span class="truncatable"><p></p><p>A year aft...
# 1    <span class="truncatable"><p></p><p>- La métho...
# 2    <span class="truncatable"><p></p><p>the UX/UI ...
# 3    <span class="truncatable"><p></p><p>When I sta...
# 4    <span class="truncatable"><p></p><p>The UX UI ...
# ..                                                 ...
# 918  <span class="truncatable"><p>The UX Design Wor...
# 919  <span class="truncatable"><p>Just some backgro...
# 920  <span class="truncatable"><p>I enjoyed the pro...
# 921  <span class="truncatable"><p>This was my first...
# 922  <span class="truncatable"><p>I really enjoyed ...
#
#                                                rawBody  ...   queryDate  \
# 0    <p>A year after completing my course, ironhack...  ...  2021-04-30
# 1    <p>- La m&eacute;thode d&#39;apprentissage est...  ...  2021-04-20
# 2    <p>the UX/UI bootcamp has been an amazing lear...  ...  2021-04-17
# 3    <p>When I started I was a little disappointed ...  ...  2021-04-15
# 4    <p>The UX UI Design bootcamp is a great way to...  ...  2021-04-14
# ..                                                 ...  ...         ...
# 918  The UX Design Workshop gave me a great underst...  ...  2016-12-15
# 919  Just some background information on myself, I ...  ...  2016-12-15
# 920  I enjoyed the program very much, gained a lot ...  ...  2016-12-15
# 921  This was my first online experience and it did...  ...  2016-12-12
# 922  I really enjoyed my time with the Springboard ...  ...  2016-12-10
#
#                        program             user overallScore comments overall  \
# 0    Web Development Part-Time  {'image': None}          1.0       []     1.0
# 1        UX/UI Design Bootcamp  {'image': None}          5.0       []     5.0
# 2        UX/UI Design Bootcamp  {'image': None}          4.0       []     5.0
# 3        UX/UI Design Bootcamp  {'image': None}          4.0       []     4.0
# 4        UX/UI Design Bootcamp  {'image': None}          4.3       []     5.0
# ..                         ...              ...          ...      ...     ...
# 918                  UX Design  {'image': None}          5.0       []     5.0
# 919                  UX Design  {'image': None}          5.0       []     5.0
# 920                  UX Design  {'image': None}          3.7       []     4.0
# 921                  UX Design  {'image': None}          5.0       []     5.0
# 922                  UX Design  {'image': None}          4.7       []     5.0
#
#     curriculum jobSupport                                        review_body  \
# 0          1.0        1.0  A year after completing my course, ironhack co...
# 1          5.0        5.0  - La méthode d'apprentissage est l'une des mei...
# 2          4.0        3.0  the UX/UI bootcamp has been an amazing learnin...
# 3          4.0        4.0  When I started I was a little disappointed but...
# 4          4.0        4.0  The UX UI Design bootcamp is a great way to tr...
# ..         ...        ...                                                ...
# 918        5.0        5.0  The UX Design Workshop gave me a great underst...
# 919        5.0        5.0  Just some background information on myself, I ...
# 920        4.0        3.0  I enjoyed the program very much, gained a lot ...
# 921        5.0        5.0  This was my first online experience and it did...
# 922        5.0        4.0  I really enjoyed my time with the Springboard ...
#
#           school
# 0       ironhack
# 1       ironhack
# 2       ironhack
# 3       ironhack
# 4       ironhack
# ..           ...
# 918  springboard
# 919  springboard
# 920  springboard
# 921  springboard
# 922  springboard
#
# [3022 rows x 21 columns]

# %%
# DataFrame.merge(right, how='inner',
# on=None,
# left_on=None, 
# right_on=None, 
# left_index=False, 
# right_index=False, 
# sort=False, 
# suffixes=('_x', '_y'), 
# copy=True, 
# indicator=False, 
# validate=None)

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# <ipython-input-77-7111c633f1e2>:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# app-academy
# springboard

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id                       description  country.id   country.name  \
#  0  15704  San Francisco, CA, United States         1.0  United States
#  1  15705  New York City, NY, United States         1.0  United States
#  2  15862                            Online         NaN            NaN
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US         6  California           CA    california     13.0
#  1             US        34    New York           NY      new-york   1507.0
#  2            NaN         1      Online       Online        online      NaN
#
#         city.name   city.keyword       school  school_id
#  0  San Francisco  san-francisco  app-academy      10525
#  1            NYC  new-york-city  app-academy      10525
#  2            NaN            NaN  app-academy      10525  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ]

# %%
locations = pd.concat(locations_list)

# %%
courses = pd.concat(courses_list)
courses.head(10)
# Out:
#                               courses       school  school_id
# 0             Cyber Security Bootcamp     ironhack      10828
# 1             Cybersecurity Part-Time     ironhack      10828
# 2             Data Analytics Bootcamp     ironhack      10828
# 3            Data Analytics Part-Time     ironhack      10828
# 4               UX/UI Design Bootcamp     ironhack      10828
# 5              UX/UI Design Part-Time     ironhack      10828
# 6            Web Development Bootcamp     ironhack      10828
# 7           Web Development Part-Time     ironhack      10828
# 0                       Bootcamp Prep  app-academy      10525
# 1  Software Engineer Track: In-Person  app-academy      10525

# %%
badges_raw = pd.concat(badges_list)
badges_raw = badges_raw.drop_duplicates(subset=['name'])

# %%
# superstore.insert(0,'Profitable?',(superstore['Profit'].apply(profitable)))

def badges_m(row):
    if row == 'Available Online':
        return 1
    elif row == 'Verified Outcomes':
        return 2
    elif row == 'Flexible Classes':
        return 3
    elif row == 'Job Guarantee':
        return 4

# %%
badges_raw.insert(0,'badges_id',(badges_raw['name'].apply(badges_m)))

# %%
badges = badges_raw

# %%
badges
# Out:
#    badges_id               name            keyword  \
# 0          1   Available Online   available_online
# 1          2  Verified Outcomes  verified_outcomes
# 2          3   Flexible Classes   flexible_classes
# 2          4      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 2             <p>School guarantees job placement</p>  app-academy      10525

# %%
badges.columns = ['badges_id','name','keyword','description','school','school_id']

# %%
badges
# Out:
#    badges_id               name            keyword  \
# 0          1   Available Online   available_online
# 1          2  Verified Outcomes  verified_outcomes
# 2          3   Flexible Classes   flexible_classes
# 2          4      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 2             <p>School guarantees job placement</p>  app-academy      10525

# %%
clean_badges = badges[['badges_id','name']]

# %%
clean_badges = clean_badges.drop_duplicates(subset=['badges_id'])

# %%
display(clean_badges)
# Out:
#    badges_id               name
# 0          1   Available Online
# 1          2  Verified Outcomes
# 2          3   Flexible Classes
# 2          4      Job Guarantee

# %%
clean_schools = badges[['school_id','school']]
clean_schools.columns = ['schools_id','name']
clean_schools = clean_schools.drop_duplicates(subset=['schools_id'])

# %%
clean_schools
# Out:
#    schools_id         name
# 0       10828     ironhack
# 3       10525  app-academy
# 6       11035  springboard

# %%
schools
# Out:
# {'ironhack': 10828, 'app-academy': 10525, 'springboard': 11035}

# %%
clean_badges_schools = badges.drop_duplicates(subset=['name','badges_id'])
clean_badges_schools = clean_badges_schools[['badges_id','school_id']]
clean_badges_schools.insert(0,'school_badges_id',(range(1,5)))
clean_badges_schools
# Out:
#    school_badges_id  badges_id  school_id
# 0                 1          1      10828
# 1                 2          2      10828
# 2                 3          3      10828
# 2                 4          4      10525

# %%
clean_comments = comments.merge(schools, how='inner', on='school')
to_drop = ['graduatingYear','tagline','body','rawBody','user','comments','review_body','anonymous','createdAt','jobTitle','hostProgramName','queryDate']
clean_comments.drop(to_drop,inplace=True,axis=1,)
clean_comments.drop(['website','description','LogoUrl','school'], inplace=True,axis=1)
clean_comments = clean_comments.fillna(0)
clean_comments['overall'] = clean_comments['overall'].apply(lambda x : float(x))
clean_comments['overallScore'] = clean_comments['overallScore'].apply(lambda x : float(x))
clean_comments['curriculum'] = clean_comments['curriculum'].apply(lambda x : float(x))
clean_comments['jobSupport'] = clean_comments['jobSupport'].apply(lambda x : float(x))

clean_comments
# Out:
#           id                     name  isAlumni                    program  \
# 0     276568  Guilherme golabek brein     False  Web Development Part-Time
# 1     276147          Charlotte Urvoy     False      UX/UI Design Bootcamp
# 2     275972                Anonymous     False      UX/UI Design Bootcamp
# 3     275872             Ahmad Khalaf     False      UX/UI Design Bootcamp
# 4     275855        Morgane Favchtein     False      UX/UI Design Bootcamp
# ...      ...                      ...       ...                        ...
# 3017  234894             Stephanie S.      True                  UX Design
# 3018  234877                 Joe Fang      True                  UX Design
# 3019  234838                    Zeina      True                  UX Design
# 3020  242681                     Jean      True                  UX Design
# 3021  234178                      Ben      True                  UX Design
#
#       overallScore  overall  curriculum  jobSupport  school_id
# 0              1.0      1.0         1.0         1.0      10828
# 1              5.0      5.0         5.0         5.0      10828
# 2              4.0      5.0         4.0         3.0      10828
# 3              4.0      4.0         4.0         4.0      10828
# 4              4.3      5.0         4.0         4.0      10828
# ...            ...      ...         ...         ...        ...
# 3017           5.0      5.0         5.0         5.0      11035
# 3018           5.0      5.0         5.0         5.0      11035
# 3019           3.7      4.0         4.0         3.0      11035
# 3020           5.0      5.0         5.0         5.0      11035
# 3021           4.7      5.0         5.0         4.0      11035
#
# [3022 rows x 9 columns]

# %%
locations_clean = locations.copy()
to_drop = ['description','country.id','country.abbrev','city.id','city.keyword','state.id','state.name','state.abbrev','state.keyword']
locations_clean.drop(to_drop,inplace=True,axis=1,)
locations_clean.rename(columns = {'id':'location_id','country.name':'country','city.name':'city'}, inplace = True)

# %%
clean_locations = locations_clean
clean_locations = clean_locations.fillna('Online')

# %%
clean_locations
# Out:
#    location_id        country           city       school  school_id
# 0        15901        Germany         Berlin     ironhack      10828
# 1        16022         Mexico    Mexico City     ironhack      10828
# 2        16086    Netherlands      Amsterdam     ironhack      10828
# 3        16088         Brazil      Sao Paulo     ironhack      10828
# 4        16109         France          Paris     ironhack      10828
# 5        16375  United States          Miami     ironhack      10828
# 6        16376          Spain         Madrid     ironhack      10828
# 7        16377          Spain      Barcelona     ironhack      10828
# 8        16709       Portugal         Lisbon     ironhack      10828
# 9        17233         Online         Online     ironhack      10828
# 0        15704  United States  San Francisco  app-academy      10525
# 1        15705  United States            NYC  app-academy      10525
# 2        15862         Online         Online  app-academy      10525
# 0        16013         Online         Online  springboard      11035

# %%
display(clean_schools)
display(clean_badges)
display(clean_badges_schools)
display(clean_comments)
display(clean_locations)
# Out:
#    schools_id         name
# 0       10828     ironhack
# 3       10525  app-academy
# 6       11035  springboard
#    badges_id               name
# 0          1   Available Online
# 1          2  Verified Outcomes
# 2          3   Flexible Classes
# 2          4      Job Guarantee
#    school_badges_id  badges_id  school_id
# 0                 1          1      10828
# 1                 2          2      10828
# 2                 3          3      10828
# 2                 4          4      10525
#           id                     name  isAlumni                    program  \
# 0     276568  Guilherme golabek brein     False  Web Development Part-Time
# 1     276147          Charlotte Urvoy     False      UX/UI Design Bootcamp
# 2     275972                Anonymous     False      UX/UI Design Bootcamp
# 3     275872             Ahmad Khalaf     False      UX/UI Design Bootcamp
# 4     275855        Morgane Favchtein     False      UX/UI Design Bootcamp
# ...      ...                      ...       ...                        ...
# 3017  234894             Stephanie S.      True                  UX Design
# 3018  234877                 Joe Fang      True                  UX Design
# 3019  234838                    Zeina      True                  UX Design
# 3020  242681                     Jean      True                  UX Design
# 3021  234178                      Ben      True                  UX Design
#
#       overallScore  overall  curriculum  jobSupport  school_id
# 0              1.0      1.0         1.0         1.0      10828
# 1              5.0      5.0         5.0         5.0      10828
# 2              4.0      5.0         4.0         3.0      10828
# 3              4.0      4.0         4.0         4.0      10828
# 4              4.3      5.0         4.0         4.0      10828
# ...            ...      ...         ...         ...        ...
# 3017           5.0      5.0         5.0         5.0      11035
# 3018           5.0      5.0         5.0         5.0      11035
# 3019           3.7      4.0         4.0         3.0      11035
# 3020           5.0      5.0         5.0         5.0      11035
# 3021           4.7      5.0         5.0         4.0      11035
#
# [3022 rows x 9 columns]
#    location_id        country           city       school  school_id
# 0        15901        Germany         Berlin     ironhack      10828
# 1        16022         Mexico    Mexico City     ironhack      10828
# 2        16086    Netherlands      Amsterdam     ironhack      10828
# 3        16088         Brazil      Sao Paulo     ironhack      10828
# 4        16109         France          Paris     ironhack      10828
# 5        16375  United States          Miami     ironhack      10828
# 6        16376          Spain         Madrid     ironhack      10828
# 7        16377          Spain      Barcelona     ironhack      10828
# 8        16709       Portugal         Lisbon     ironhack      10828
# 9        17233         Online         Online     ironhack      10828
# 0        15704  United States  San Francisco  app-academy      10525
# 1        15705  United States            NYC  app-academy      10525
# 2        15862         Online         Online  app-academy      10525
# 0        16013         Online         Online  springboard      11035

# %%
#################CREATING A CONNECTION TO THE DATABASE#####################
import pymysql
import getpass
import mysql.connector
from sqlalchemy import create_engine

# Connect to the database

host="database-1.cesj3b2ko52z.us-east-2.rds.amazonaws.com"
port=3306
dbname="project"
user="root"
password="12345678"


#engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
#                       .format(user="root",
#                               pw="1234",
#                               db="project"))

engine = create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'
            .format(user, password,host, dbname)).connect()


# create cursor

# %%
clean_comments.to_sql('comments', con = engine,if_exists = 'replace')

# %%
clean_schools.to_sql('schools', con = engine,if_exists = 'replace')

# %%
clean_badges.to_sql('badges', con = engine,if_exists = 'replace')

# %%
clean_badges_schools.to_sql('school_badges_id', con = engine,if_exists = 'replace')

# %%
clean_locations.to_sql('locations', con = engine,if_exists = 'replace')

# %%
query = pd.read_sql_query("""SELECT * FROM comments;""", engine)

# %%
query
# Out:
#       index      id                     name  isAlumni  \
# 0         0  276568  Guilherme golabek brein         0
# 1         1  276147          Charlotte Urvoy         0
# 2         2  275972                Anonymous         0
# 3         3  275872             Ahmad Khalaf         0
# 4         4  275855        Morgane Favchtein         0
# ...     ...     ...                      ...       ...
# 3017   3017  234894             Stephanie S.         1
# 3018   3018  234877                 Joe Fang         1
# 3019   3019  234838                    Zeina         1
# 3020   3020  242681                     Jean         1
# 3021   3021  234178                      Ben         1
#
#                         program  overallScore  overall  curriculum  \
# 0     Web Development Part-Time           1.0      1.0         1.0
# 1         UX/UI Design Bootcamp           5.0      5.0         5.0
# 2         UX/UI Design Bootcamp           4.0      5.0         4.0
# 3         UX/UI Design Bootcamp           4.0      4.0         4.0
# 4         UX/UI Design Bootcamp           4.3      5.0         4.0
# ...                         ...           ...      ...         ...
# 3017                  UX Design           5.0      5.0         5.0
# 3018                  UX Design           5.0      5.0         5.0
# 3019                  UX Design           3.7      4.0         4.0
# 3020                  UX Design           5.0      5.0         5.0
# 3021                  UX Design           4.7      5.0         5.0
#
#       jobSupport  school_id
# 0            1.0      10828
# 1            5.0      10828
# 2            3.0      10828
# 3            4.0      10828
# 4            4.0      10828
# ...          ...        ...
# 3017         5.0      11035
# 3018         5.0      11035
# 3019         3.0      11035
# 3020         5.0      11035
# 3021         4.0      11035
#
# [3022 rows x 10 columns]
