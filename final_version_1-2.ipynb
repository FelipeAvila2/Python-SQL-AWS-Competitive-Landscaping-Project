# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'la-capsule' : 10853,
'app-academy' : 10525,
'springboard' : 11035,
'metis' : 10886,
'practicum-by-yandex' : 11225,
'le-wagon' : 10868,
'academia-de-codigo' :10494 ,
'react-graphql-academy' : 10972
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
# comments = []

# for school in schools.keys():
#    print(school)
#    comments.append(get_comments_school(school))
    
comments = [get_comments_school(key) for key in schools.keys()]

comments = pd.concat(comments)
comments.sample(50)
# Out:
#           id                               name  anonymous  \
# 673   240929                         Alec Plehn      False
# 379   256160                     Sergui Morejón      False
# 562   244853                            Jackson      False
# 99    268230                        hans cameus      False
# 116   273517                         Emily Paul      False
# 1720  260992                 Camille Franceschi      False
# 405   264904                        Jules Ronne      False
# 23    272680                    Ariane Gaudeaux      False
# 397   264274                  Taylor Brightwell      False
# 1175  246374                     Kaylin Bittner      False
# 680   258830                      Terri Hounsom      False
# 1910  234730                           Jonathan      False
# 22    275685                       Taten Knight      False
# 913   250543                               Iris      False
# 820   254386                             Thomas      False
# 858   252238                          Anonymous       True
# 302   266487                Anastasiia Makarova      False
# 253   268408    Sascha Antonio Montero Balevich      False
# 335   265962                         Dan Howitt      False
# 673   247377                     Craig Paulette      False
# 825   254154                       Emma LAURENT      False
# 853   237135                               LeoL      False
# 833   253734                           Santiago      False
# 890   236304                         David Wong      False
# 651   259906                   Simon Stefanelli      False
# 534   234694  Manuel Alejandro Matus de Quevedo      False
# 5     276802                         Noah Jaffe      False
# 898   250701                Ruben den Hollander      False
# 23    276492                            Charles      False
# 1211  238603                           Martinho      False
# 551   254662                      Daniel Duncum      False
# 211   263855                         Bart Weber      False
# 491   245848                             Miguel      False
# 371   257961                     Daniela castro      False
# 569   261152                              Daria      False
# 990   251013                     Alexis Dewerdt      False
# 538   261881                 Cecilia Marcellesi      False
# 1736  238377                    Florent LIENARD      False
# 725   257743                             Pietro      False
# 498   263081                               Iram      False
# 704   258190                     Eugénie Inbona      False
# 1268  245233                    Frédéric Curier      False
# 1556  235517                    Alexander Clapp      False
# 1519  232510                         Irina Popa      False
# 288   268204                     Polina Maguire      False
# 1270  245198                   David Carr-Gregg      False
# 872   240371                      Omar Al-Naimi      False
# 821   241752                       Ritesh Patel      False
# 499   259211                     Kristen Colley      False
# 687   236987                           Laurette      False
#
#                  hostProgramName  graduatingYear isAlumni  \
# 673         Software Engineering          2018.0     True
# 379         Software Engineering          2019.0    False
# 562         Software Engineering          2018.0     True
# 99                          None          2020.0    False
# 116                         None          2021.0    False
# 1720  Full-Stack Web Development          2017.0     None
# 405         Software Engineering          2020.0    False
# 23                          None          2021.0     True
# 397            Digital Marketing          2019.0    False
# 1175        Software Engineering          2018.0     True
# 680         Software Engineering          2019.0    False
# 1910                        None          2016.0     True
# 22                          None          2021.0     True
# 913         Software Engineering          2019.0     True
# 820         Software Engineering          2019.0     True
# 858         Software Engineering          2018.0     True
# 302         Software Engineering          2020.0    False
# 253                         None          2020.0     True
# 335         Software Engineering          2020.0    False
# 673                 Data Science          2019.0     True
# 825         Software Engineering          2019.0     True
# 853                         None          2017.0     True
# 833         Software Engineering          2019.0     True
# 890                         None          2017.0     True
# 651                         None          2019.0    False
# 534         Software Engineering          2018.0     True
# 5                           None          2020.0    False
# 898         Software Engineering          2019.0     True
# 23                          None          2021.0    False
# 1211        Software Engineering          2018.0     True
# 551                         None          2019.0     True
# 211                 UX/UI Design          2020.0    False
# 491         Software Engineering          2018.0     True
# 371                 UX/UI Design          2019.0     True
# 569         Software Engineering          2019.0    False
# 990         Software Engineering          2019.0     True
# 538         Software Engineering          2019.0    False
# 1736                        None          2017.0     True
# 725         Software Engineering          2019.0    False
# 498         Software Engineering          2020.0    False
# 704         Software Engineering          2019.0    False
# 1268        Software Engineering          2018.0     True
# 1556        Software Engineering          2018.0    False
# 1519        Software Engineering          2018.0     True
# 288                         None          2020.0    False
# 1270        Software Engineering          2018.0     True
# 872                         None          2017.0     True
# 821                 UX/UI Design          2018.0     True
# 499                 Data Science          2019.0    False
# 687         Software Engineering          2018.0     True
#
#                  jobTitle                                            tagline  \
# 673                  None                     Amazing experience at Ironhack
# 379                  None                          Ironhack change my life !
# 562    Software Developer  Had no coding experience before, now I'm a web...
# 99                                                     Amazing experience ..
# 116      Product Designer                                   Believe the hype
# 1720                 None                                 Amazing experience
# 405                                  Best pedagogic experience I’ve ever had
# 23         UX/UI Designer                                      Just MAGICAL!
# 397                                      Mentorship and practice for the win
# 1175                 None  Le Wagon was wonderful experience and continue...
# 680                  None  Life-changing - highly recommend Le Wagon London!
# 1910         Développeur                      Le wagon : un tournant à 180°.
# 22                                              Awesome Learning Experience!
# 913                  None               A great way to learn web development
# 820                  None                           Life changing experience
# 858     Software Engineer  An accelerated first step for anyone committed...
# 302                                                      Valuable experience
# 253                                                                      Bad
# 335                        Amazing experience, incredible teaching, and d...
# 673                  None                           Look closely at this one
# 825                  None               Great experience @ Le Wagon Bordeaux
# 853                  None                                        Get Ready!!
# 833                  None                             Great in so many ways!
# 890                  None  It's hard and not for everyone, but if you mak...
# 651                  None             Great time discovering web development
# 534   Web Content Analyst                          The best experience ever!
# 5            Data analyst  Metis was instrumental in getting me my first ...
# 898                  None                              Great Coding Bootcamp
# 23    Front End Developer                                       Impressive !
# 1211                 None                         Thank you very much, guys!
# 551                  None                 Springboard intro to data analysis
# 211                        An intensive 9 week course filled with non-sto...
# 491                  None                           Best bootcamp experience
# 371                  None                                  Além do esperado!
# 569                  None                                Rio de Janeiro #330
# 990                  None                         Le Wagon Lyon,  batch #218
# 538                  None                 By far the best decision I've made
# 1736                 None                             Best investment so far
# 725                  None                                     Great Bootcamp
# 498                  None                               The best experience!
# 704                  None                               Work hard, play hard
# 1268   Full-stack web Dev                         Le Wagon, Great experience
# 1556         Entrepreneur                  Le Wagon exceeded my expectations
# 1519                 None  Le Wagon Lisbon Batch#122 - An amazing experience
# 288           UX Designer  Highly recommended for those who are changing ...
# 1270     Junior Developer                                 Jump of le Wagon!!
# 872                  None          Spring board knows how teach data science
# 821                  None                      Enjoyed the UX design course.
# 499                  None                                 AWESOME experience
# 687                  None                              Super fast, super fun
#
#                                                    body  \
# 673   <span class="truncatable"><p>If you want to st...
# 379   <span class="truncatable"><p>I remember when I...
# 562   <span class="truncatable"><p>Before App Academ...
# 99    <span class="truncatable"><p></p><p>I followed...
# 116   <span class="truncatable"><p></p><p>My experie...
# 1720  <span class="truncatable"><p>After 2.5 years w...
# 405   <span class="truncatable"><p>After a Master de...
# 23    <span class="truncatable"><p></p><p>Although i...
# 397   <span class="truncatable"><p>What set's the Sp...
# 1175  <span class="truncatable"><p>After attending L...
# 680   <span class="truncatable"><p></p><p>I had no t...
# 1910  <span class="truncatable"><p>Géophysicien fraî...
# 22    <span class="truncatable"><p></p><p>This progr...
# 913   <span class="truncatable"><p>Coming from a non...
# 820   <span class="truncatable"><p>In the early year...
# 858   <span class="truncatable"><p>For anyone commit...
# 302   <span class="truncatable"><p>For some reason I...
# 253   <span class="truncatable"><p>Got thrown out of...
# 335   <span class="truncatable"><p>Excellent bootcam...
# 673   <span class="truncatable"><p>Everyone has diff...
# 825   <span class="truncatable"><p>I joined batch #2...
# 853   <span class="truncatable"><p>So, coming from a...
# 833   <span class="truncatable"><p>More than a bootc...
# 890   <span class="truncatable"><p>This stuff is tou...
# 651   <span class="truncatable"><p></p><p>I went to ...
# 534   <p>It was definitely the best experience, not ...
# 5     <span class="truncatable"><p></p><p>The setup ...
# 898   <span class="truncatable"><p>After researching...
# 23    <span class="truncatable"><p></p><p>Hi, my nam...
# 1211  <p>Amazing. Great environment and resources. I...
# 551   <p><p>Very well managed program, teaches you t...
# 211   <span class="truncatable"><p>The teachers and ...
# 491   <span class="truncatable"><p>The Ironhack expe...
# 371   <span class="truncatable"><p>A experiência da ...
# 569   <span class="truncatable"><p>Before Le Wagon I...
# 990   <span class="truncatable"><p>The experience wa...
# 538   <span class="truncatable"><p>After completing ...
# 1736  <span class="truncatable"><p>Hi, I am Florent ...
# 725   <span class="truncatable"><p>I really enjoyed ...
# 498   <span class="truncatable"><p>I joined Le Wagon...
# 704   <span class="truncatable"><p></p><p>You do not...
# 1268  <span class="truncatable"><p>As a serial entre...
# 1556  <span class="truncatable"><p>Prior to starting...
# 1519  <span class="truncatable"><p>Before joining Le...
# 288   <span class="truncatable"><p>It took me longer...
# 1270  <span class="truncatable"><p>If your looking t...
# 872   <span class="truncatable"><p>I took Data Scien...
# 821   <p>UX design course with springboard was amazi...
# 499   <span class="truncatable"><p>Seriously, Spring...
# 687   <span class="truncatable"><p>I attended App Ac...
#
#                                                 rawBody  ...   queryDate  \
# 673   If you want to start programming but dont know...  ...  2018-04-11
# 379   I remember when I emigrated here to the US, an...  ...  2019-10-07
# 562   Before App Academy, all I knew was that I want...  ...  2018-09-24
# 99    <p>I followed a first training named Simplon w...  ...  2020-09-04
# 116   <p>My experience with Springboard has been tre...  ...  2021-02-09
# 1720  After 2.5 years working in M&A, I was looking ...  ...  2017-10-04
# 405   After a Master degree in digital project manag...  ...  2020-05-24
# 23    <p>Although it was remote, it was just MAGICAL...  ...  2021-01-22
# 397   What set's the Springboard Digital Marketing c...  ...  2020-05-05
# 1175  After attending Le Wagon, you are limited only...  ...  2019-01-08
# 680   <p>I had no technical background or experience...  ...  2019-11-16
# 1910  Géophysicien fraîchement diplômé, je me suis t...  ...  2016-09-29
# 22    <p>This program is great! It has a modern curr...  ...  2021-04-09
# 913   Coming from a non-tech background, I tried lea...  ...  2019-07-05
# 820   In the early years of my studies, I was in a b...  ...  2019-09-11
# 858   For anyone committed to seriously challenging ...  ...  2019-08-03
# 302   For some reason I decided to change my profess...  ...  2020-07-17
# 253   Got thrown out of the bootcamp for not underst...  ...  2020-09-12
# 335   Excellent bootcamp. Le Wagon's slogan "change ...  ...  2020-07-01
# 673   Everyone has different needs, so definitely ma...  ...  2019-03-22
# 825   I joined batch #276 in Bordeaux, France, and I...  ...  2019-09-11
# 853   So, coming from a background in art, everythin...  ...  2017-08-09
# 833   More than a bootcamp. \r\n\r\nHard, challengin...  ...  2019-08-26
# 890   This stuff is tough. It's going to take a lot ...  ...  2017-06-01
# 651   <p>I went to Le Wagon after a freelance period...  ...  2019-12-16
# 534   It was definitely the best experience, not jus...  ...  2018-10-17
# 5     <p>The setup of Metis was rigorous, with an ac...  ...  2021-05-08
# 898   After researching many coding bootcamps and fo...  ...  2019-07-13
# 23    <p>Hi, my name is Charles ! I am 27 and I was ...  ...  2021-04-28
# 1211  Amazing. Great environment and resources. I th...  ...  2018-11-29
# 551   <p>Very well managed program, teaches you the ...  ...  2019-09-16
# 211   The teachers and teaching assistants are extre...  ...  2020-04-24
# 491   The Ironhack experience is tough but at the en...  ...  2018-11-29
# 371   A experiência da formação é pensada de ponta a...  ...  2019-10-22
# 569   Before Le Wagon I used to work in sports marke...  ...  2020-01-18
# 990   The experience was short but intense. I am imp...  ...  2019-05-07
# 538   After completing a Business degree at Universi...  ...  2020-02-12
# 1736  Hi, I am Florent and I’ve been studying at le ...  ...  2017-09-29
# 725   I really enjoyed my 9 weeks at Le Wagon. I fee...  ...  2019-10-16
# 498   I joined Le Wagon in 2020. It was a tough 9 we...  ...  2020-03-30
# 704   <p>You do not learn to read and write to becom...  ...  2019-10-28
# 1268  As a serial entrepreneur, I have always been k...  ...  2018-10-12
# 1556  Prior to starting my MBA at INSEAD i wanted to...  ...  2018-04-04
# 1519  Before joining Le Wagon, I had never had a rel...  ...  2018-04-20
# 288   It took me longer than the estimated 6-8 month...  ...  2020-09-03
# 1270  If your looking to pull the trigger and commit...  ...  2018-10-11
# 872   I took Data Science Career Track course after ...  ...  2017-12-06
# 821   UX design course with springboard was amazing,...  ...  2018-07-26
# 499   Seriously, Springboard got the job done.\r\n\r...  ...  2019-11-25
# 687   I attended App Academy in early 2018. Unlike m...  ...  2018-03-18
#
#                                        program             user overallScore  \
# 673        Full-time Web Development Bootcamp   {'image': None}          5.0
# 379         Full-time Web Development Bootcamp  {'image': None}          5.0
# 562         Software Engineer Track: In-Person  {'image': None}          5.0
# 99                                              {'image': None}          5.0
# 116                            UX Career Track  {'image': None}          5.0
# 1720                         FullStack program  {'image': None}          5.0
# 405         Web Development Course - Full-Time  {'image': None}          5.0
# 23                                              {'image': None}          5.0
# 397             Digital Marketing Career Track  {'image': None}          4.0
# 1175         FullStack program - 35+ locations  {'image': None}          5.0
# 680                                             {'image': None}          5.0
# 1910         FullStack program - 35+ locations  {'image': None}          5.0
# 22             Software Engineer Track: Online  {'image': None}          5.0
# 913          FullStack program - 35+ locations  {'image': None}          4.7
# 820                                       None  {'image': None}          5.0
# 858          FullStack program - 35+ locations  {'image': None}          4.5
# 302         Web Development Course - Full-Time  {'image': None}          5.0
# 253         Web Development Course - Full-Time  {'image': None}          1.0
# 335         Web Development Course - Full-Time  {'image': None}          5.0
# 673                  Data Science Career Track  {'image': None}          5.0
# 825                                       None  {'image': None}          5.0
# 853                              Bootcamp Prep  {'image': None}          4.3
# 833                                       None  {'image': None}          5.0
# 890         Software Engineer Track: In-Person  {'image': None}          4.7
# 651                                             {'image': None}          5.0
# 534                  Part-time Web Development  {'image': None}          5.0
# 5     Data Science & Machine Learning Bootcamp  {'image': None}          5.0
# 898          FullStack program - 35+ locations  {'image': None}          5.0
# 23          Web Development Course - Full-Time  {'image': None}          5.0
# 1211         FullStack program - 35+ locations  {'image': None}          5.0
# 551                                             {'image': None}          5.0
# 211                      UX/UI Design Bootcamp  {'image': None}          4.0
# 491        Full-time Web Development Bootcamp   {'image': None}          5.0
# 371                     Part-time UX/UI Design  {'image': None}          4.7
# 569                          FullStack program  {'image': None}          5.0
# 990          FullStack program - 35+ locations  {'image': None}          5.0
# 538                          FullStack program  {'image': None}          5.0
# 1736         FullStack program - 35+ locations  {'image': None}          5.0
# 725                          FullStack program  {'image': None}          5.0
# 498                          FullStack program  {'image': None}          5.0
# 704                                             {'image': None}          5.0
# 1268         FullStack program - 35+ locations  {'image': None}          5.0
# 1556         FullStack program - 35+ locations  {'image': None}          5.0
# 1519         FullStack program - 35+ locations  {'image': None}          5.0
# 288                            UX Career Track  {'image': None}          5.0
# 1270         FullStack program - 35+ locations  {'image': None}          5.0
# 872                  Data Science Career Track  {'image': None}          5.0
# 821                                  UX Design  {'image': None}          5.0
# 499                  Data Science Career Track  {'image': None}          4.0
# 687         Software Engineer Track: In-Person  {'image': None}          4.7
#
#                                                comments overall curriculum  \
# 673                                                  []     5.0        5.0
# 379                                                  []     5.0        5.0
# 562                                                  []     5.0        5.0
# 99                                                   []     5.0        5.0
# 116                                                  []     5.0        5.0
# 1720                                                 []     5.0        5.0
# 405                                                  []     5.0        5.0
# 23                                                   []     5.0        5.0
# 397                                                  []     4.0        3.0
# 1175                                                 []     5.0        5.0
# 680                                                  []     5.0        5.0
# 1910                                                 []     5.0        5.0
# 22                                                   []     5.0        5.0
# 913                                                  []     5.0        5.0
# 820                                                  []     5.0        5.0
# 858                                                  []     4.0        5.0
# 302                                                  []     5.0        5.0
# 253   [{'name': 'Le Wagon Team', 'email': 'gus@lewag...     1.0        1.0
# 335                                                  []     5.0        5.0
# 673                                                  []     5.0        5.0
# 825                                                  []     5.0        5.0
# 853                                                  []     5.0        4.0
# 833                                                  []     5.0        NaN
# 890                                                  []     5.0        4.0
# 651                                                  []     5.0        5.0
# 534                                                  []     5.0        5.0
# 5                                                    []     5.0        5.0
# 898                                                  []     5.0        5.0
# 23                                                   []     5.0        5.0
# 1211                                                 []     5.0        5.0
# 551                                                  []     5.0        5.0
# 211                                                  []     4.0        4.0
# 491                                                  []     5.0        5.0
# 371                                                  []     5.0        4.0
# 569                                                  []     5.0        5.0
# 990                                                  []     5.0        5.0
# 538                                                  []     5.0        5.0
# 1736                                                 []     5.0        5.0
# 725                                                  []     5.0        5.0
# 498                                                  []     5.0        5.0
# 704                                                  []     5.0        5.0
# 1268                                                 []     5.0        5.0
# 1556                                                 []     5.0        5.0
# 1519                                                 []     5.0        5.0
# 288                                                  []     5.0        5.0
# 1270                                                 []     5.0        5.0
# 872                                                  []     5.0        5.0
# 821                                                  []     5.0        5.0
# 499                                                  []     5.0        2.0
# 687                                                  []     5.0        5.0
#
#      jobSupport                                        review_body  \
# 673         5.0  If you want to start programming but dont know...
# 379         5.0  I remember when I emigrated here to the US, an...
# 562         5.0  Before App Academy, all I knew was that I want...
# 99          5.0  I followed a first training named Simplon whic...
# 116         5.0  My experience with Springboard has been tremen...
# 1720        5.0  After 2.5 years working in M&amp;A, I was look...
# 405         5.0  After a Master degree in digital project manag...
# 23          5.0  Although it was remote, it was just MAGICAL. I...
# 397         5.0  What set's the Springboard Digital Marketing c...
# 1175        5.0  After attending Le Wagon, you are limited only...
# 680         5.0  I had no technical background or experience at...
# 1910        5.0  Géophysicien fraîchement diplômé, je me suis t...
# 22          NaN  This program is great! It has a modern curricu...
# 913         4.0  Coming from a non-tech background, I tried lea...
# 820         5.0  In the early years of my studies, I was in a b...
# 858         NaN  For anyone committed to seriously challenging ...
# 302         5.0  For some reason I decided to change my profess...
# 253         1.0  Got thrown out of the bootcamp for not underst...
# 335         5.0  Excellent bootcamp. Le Wagon's slogan "change ...
# 673         5.0  Everyone has different needs, so definitely ma...
# 825         NaN  I joined batch #276 in Bordeaux, France, and I...
# 853         4.0  So, coming from a background in art, everythin...
# 833         NaN  More than a bootcamp. Hard, challenging, it ta...
# 890         5.0  This stuff is tough. It's going to take a lot ...
# 651         5.0  I went to Le Wagon after a freelance periode b...
# 534         5.0  It was definitely the best experience, not jus...
# 5           5.0  The setup of Metis was rigorous, with an accel...
# 898         5.0  After researching many coding bootcamps and fo...
# 23          5.0  Hi, my name is Charles ! I am 27 and I was a M...
# 1211        5.0  Amazing. Great environment and resources. I th...
# 551         5.0  Very well managed program, teaches you the ins...
# 211         4.0  The teachers and teaching assistants are extre...
# 491         5.0  The Ironhack experience is tough but at the en...
# 371         5.0  A experiência da formação é pensada de ponta a...
# 569         5.0  Before Le Wagon I used to work in sports marke...
# 990         5.0  The experience was short but intense. I am imp...
# 538         5.0  After completing a Business degree at Universi...
# 1736        5.0  Hi, I am Florent and I’ve been studying at le ...
# 725         5.0  I really enjoyed my 9 weeks at Le Wagon. I fee...
# 498         5.0  I joined Le Wagon in 2020. It was a tough 9 we...
# 704         5.0  You do not learn to read and write to become a...
# 1268        5.0  As a serial entrepreneur, I have always been k...
# 1556        NaN  Prior to starting my MBA at INSEAD i wanted to...
# 1519        5.0  Before joining Le Wagon, I had never had a rel...
# 288         NaN  It took me longer than the estimated 6-8 month...
# 1270        5.0  If your looking to pull the trigger and commit...
# 872         5.0  I took Data Science Career Track course after ...
# 821         NaN  UX design course with springboard was amazing,...
# 499         5.0  Seriously, Springboard got the job done.Excell...
# 687         4.0  I attended App Academy in early 2018. Unlike m...
#
#            school
# 673      ironhack
# 379      ironhack
# 562   app-academy
# 99     la-capsule
# 116   springboard
# 1720     le-wagon
# 405      le-wagon
# 23       ironhack
# 397   springboard
# 1175     le-wagon
# 680      le-wagon
# 1910     le-wagon
# 22    app-academy
# 913      le-wagon
# 820      le-wagon
# 858      le-wagon
# 302      le-wagon
# 253      le-wagon
# 335      le-wagon
# 673   springboard
# 825      le-wagon
# 853   app-academy
# 833      le-wagon
# 890   app-academy
# 651      le-wagon
# 534      ironhack
# 5           metis
# 898      le-wagon
# 23       le-wagon
# 1211     le-wagon
# 551   springboard
# 211      ironhack
# 491      ironhack
# 371      ironhack
# 569      le-wagon
# 990      le-wagon
# 538      le-wagon
# 1736     le-wagon
# 725      le-wagon
# 498      le-wagon
# 704      le-wagon
# 1268     le-wagon
# 1556     le-wagon
# 1519     le-wagon
# 288   springboard
# 1270     le-wagon
# 872   springboard
# 821   springboard
# 499   springboard
# 687   app-academy
#
# [50 rows x 21 columns]

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# <ipython-input-3-7111c633f1e2>:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# la-capsule
# app-academy
# springboard
# metis
# practicum-by-yandex
# le-wagon
# academia-de-codigo
# react-graphql-academy

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id        description  country.id country.name country.abbrev  city.id  \
#  0  15863      Paris, France          38       France             FR    31136
#  1  17050       Lyon, France          38       France             FR    31106
#  2  17450  Marseille, France          38       France             FR    31129
#
#     city.name city.keyword      school  school_id
#  0      Paris        paris  la-capsule      10853
#  1       Lyon         lyon  la-capsule      10853
#  2  Marseille    marseille  la-capsule      10853  ,
#        id                       description  country.id   country.name  \
#  0  15704  San Francisco, CA, United States         1.0  United States
#  1  15705  New York City, NY, United States         1.0  United States
#  2  15862                            Online         NaN            NaN
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US         6  California           CA    california     13.0
#  1             US        34    New York           NY      new-york   1507.0
#  2            NaN         1      Online       Online        online      NaN
#
#         city.name   city.keyword       school  school_id
#  0  San Francisco  san-francisco  app-academy      10525
#  1            NYC  new-york-city  app-academy      10525
#  2            NaN            NaN  app-academy      10525  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ,
#        id           description  country.id   country.name country.abbrev  \
#  0  15718     New York City, NY         1.0  United States             US
#  1  16079     San Francisco, CA         1.0  United States             US
#  2  16081                Online         NaN            NaN            NaN
#  3  16263           Chicago, IL         1.0  United States             US
#  4  16278           Seattle, WA         1.0  United States             US
#  5  16803  Singapore, Singapore        56.0      Singapore             SG
#
#     state.id  state.name state.abbrev state.keyword  city.id      city.name  \
#  0      34.0    New York           NY      new-york   1507.0            NYC
#  1       6.0  California           CA    california     13.0  San Francisco
#  2       1.0      Online       Online        online      NaN            NaN
#  3      15.0    Illinois           IL      illinois     39.0        Chicago
#  4      49.0  Washington           WA    washington     97.0        Seattle
#  5       NaN         NaN          NaN           NaN  31154.0      Singapore
#
#      city.keyword school  school_id
#  0  new-york-city  metis      10886
#  1  san-francisco  metis      10886
#  2            NaN  metis      10886
#  3        chicago  metis      10886
#  4        seattle  metis      10886
#  5      singapore  metis      10886  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  17154      Online         1     Online       Online        online
#
#                  school  school_id
#  0  practicum-by-yandex      11225  ,
#         id                  description  country.id          country.name  \
#  0   15803         Melbourne, Australia          20             Australia
#  1   15904          Casablanca, Morocco          44               Morocco
#  2   15906      Buenos Aires, Argentina          60             Argentina
#  3   15964            Brussels, Belgium          46               Belgium
#  4   15979                 Milan, Italy          39                 Italy
#  5   15996               Chengdu, China          15                 China
#  6   16039          Mexico City, Mexico          29                Mexico
#  7   16049       Amsterdam, Netherlands          59           Netherlands
#  8   16106            Sao Paulo, Brazil          42                Brazil
#  9   16124             Barcelona, Spain          12                 Spain
#  10  16145             Bordeaux, France          38                France
#  11  16146          Copenhagen, Denmark          47               Denmark
#  12  16147                Lille, France          38                France
#  13  16148             Lisbon, Portugal          28              Portugal
#  14  16149              Bali, Indonesia          35             Indonesia
#  15  16150               Nantes, France          38                France
#  16  16274      Rio de Janeiro , Brazil          42                Brazil
#  17  16275            Marseille, France          38                France
#  18  16282             Montreal, Canada           2                Canada
#  19  16283              Shanghai, China          15                 China
#  20  16307       Belo Horizonte, Brazil          42                Brazil
#  21  16407                 Tokyo, Japan          48                 Japan
#  22  16408                 Lyon, France          38                France
#  23  16478             Tel Aviv, Israel           5                Israel
#  24  16570                 Kyoto, Japan          48                 Japan
#  25  16765              Berlin, Germany          57               Germany
#  26  16767                Paris, France          38                France
#  27  16775              Shenzhen, China          15                 China
#  28  16776        Lausanne, Switzerland          32           Switzerland
#  29  16800                Madrid, Spain          12                 Spain
#  30  16804                 Oslo, Norway          52                Norway
#  31  16805               Rennes, France          38                France
#  32  16936         Singapore, Singapore          56             Singapore
#  33  16967              London, England          61               England
#  34  16968                  Rome, Italy          39                 Italy
#  35  17128            Stockholm, Sweden          37                Sweden
#  36  17129                 Seoul, Korea          55           South Korea
#  37  17157             Istanbul, Turkey         237                Turkey
#  38  17188              Toronto, Canada           2                Canada
#  39  17314  Dubai, United Arab Emirates          34  United Arab Emirates
#  40  17395              Munich, Germany          57               Germany
#  41  17476              Santiago, Chile          22                 Chile
#  42  17732       Saint Pierre, Mauritus         171             Mauritius
#  43  17765                 Nice, France          38                France
#  44  17772             Cologne, Germany          57               Germany
#  45  17835                   Lima, Peru         196                  Peru
#
#     country.abbrev  city.id        city.name    city.keyword    school  \
#  0              AU    31174        Melbourne       melbourne  le-wagon
#  1              MA    31119       Casablanca      casablanca  le-wagon
#  2              AR    31171     Buenos Aires    buenos-aires  le-wagon
#  3              BE    31125         Brussels        brussels  le-wagon
#  4              IT    31107            Milan           milan  le-wagon
#  5              CN    31126          Chengdu         chengdu  le-wagon
#  6              MX    31175      Mexico City     mexico-city  le-wagon
#  7              NL    31168        Amsterdam       amsterdam  le-wagon
#  8              BR    31121        Sao Paulo       sao-paulo  le-wagon
#  9              ES    31170        Barcelona       barcelona  le-wagon
#  10             FR    31124         Bordeaux        bordeaux  le-wagon
#  11             DK    31127       Copenhagen      copenhagen  le-wagon
#  12             FR    31128            Lille           lille  le-wagon
#  13             PT    31075           Lisbon          lisbon  le-wagon
#  14             ID    31169             Bali            bali  le-wagon
#  15             FR    31130           Nantes          nantes  le-wagon
#  16             BR    31131  Rio de Janeiro   rio-de-janeiro  le-wagon
#  17             FR    31129        Marseille       marseille  le-wagon
#  18             CA    31135         Montreal        montreal  le-wagon
#  19             CN    31108         Shanghai        shanghai  le-wagon
#  20             BR    31123   Belo Horizonte  belo-horizonte  le-wagon
#  21             JP    31132            Tokyo           tokyo  le-wagon
#  22             FR    31106             Lyon            lyon  le-wagon
#  23             IL    31079         Tel Aviv        tel-aviv  le-wagon
#  24             JP    31134            Kyoto           kyoto  le-wagon
#  25             DE    31156           Berlin          berlin  le-wagon
#  26             FR    31136            Paris           paris  le-wagon
#  27             CN    31164         Shenzhen        shenzhen  le-wagon
#  28             CH    31163         Lausanne        lausanne  le-wagon
#  29             ES    31052           Madrid          madrid  le-wagon
#  30             NO    31145             Oslo            oslo  le-wagon
#  31             FR    31147           Rennes          rennes  le-wagon
#  32             SG    31154        Singapore       singapore  le-wagon
#  33             GB    31176           London          london  le-wagon
#  34             IT    31180             Rome            rome  le-wagon
#  35             SE    31109        Stockholm       stockholm  le-wagon
#  36             KR    31151            Seoul            seol  le-wagon
#  37             TR    31193         Istanbul        istanbul  le-wagon
#  38             CA    31152          Toronto         toronto  le-wagon
#  39             AE    31093            Dubai           dubai  le-wagon
#  40             DE    31158           Munich          munich  le-wagon
#  41             CL    31067         Santiago        santiago  le-wagon
#  42             MU    31246     Saint Pierre    saint-pierre  le-wagon
#  43             FR    31239             Nice            nice  le-wagon
#  44             DE    31254          Cologne         cologne  le-wagon
#  45             PE    31256             Lima            lima  le-wagon
#
#      school_id
#  0       10868
#  1       10868
#  2       10868
#  3       10868
#  4       10868
#  5       10868
#  6       10868
#  7       10868
#  8       10868
#  9       10868
#  10      10868
#  11      10868
#  12      10868
#  13      10868
#  14      10868
#  15      10868
#  16      10868
#  17      10868
#  18      10868
#  19      10868
#  20      10868
#  21      10868
#  22      10868
#  23      10868
#  24      10868
#  25      10868
#  26      10868
#  27      10868
#  28      10868
#  29      10868
#  30      10868
#  31      10868
#  32      10868
#  33      10868
#  34      10868
#  35      10868
#  36      10868
#  37      10868
#  38      10868
#  39      10868
#  40      10868
#  41      10868
#  42      10868
#  43      10868
#  44      10868
#  45      10868  ,
#        id                description  country.id country.name country.abbrev  \
#  0  16627           Lisbon, Portugal          28     Portugal             PT
#  1  16771            Porto, Portugal          28     Portugal             PT
#  2  16798  Terceira Island, Portugal          28     Portugal             PT
#  3  16801           Fundao, Portugal          28     Portugal             PT
#
#     city.id        city.name     city.keyword              school  school_id
#  0    31075           Lisbon           lisbon  academia-de-codigo      10494
#  1    31102            Porto            porto  academia-de-codigo      10494
#  2    31161  Terceira Island  terceira-island  academia-de-codigo      10494
#  3    31140           Fundao           fundao  academia-de-codigo      10494  ,
#        id             description  country.id    country.name country.abbrev  \
#  0  15748         London, England        11.0  United Kingdom             GB
#  1  16749        Lisbon, Portugal        28.0        Portugal             PT
#  2  17023  Amsterdam, Netherlands        59.0     Netherlands             NL
#  3  17242                  Online         NaN             NaN            NaN
#  4  17251         Berlin, Germany        57.0         Germany             DE
#  5  17252        Barcelona, Spain        12.0           Spain             ES
#
#     city.id  city.name city.keyword  state.id state.name state.abbrev  \
#  0  31176.0     London       london       NaN        NaN          NaN
#  1  31075.0     Lisbon       lisbon       NaN        NaN          NaN
#  2  31168.0  Amsterdam    amsterdam       NaN        NaN          NaN
#  3      NaN        NaN          NaN       1.0     Online       Online
#  4  31156.0     Berlin       berlin       NaN        NaN          NaN
#  5  31170.0  Barcelona    barcelona       NaN        NaN          NaN
#
#    state.keyword                 school  school_id
#  0           NaN  react-graphql-academy      10972
#  1           NaN  react-graphql-academy      10972
#  2           NaN  react-graphql-academy      10972
#  3        online  react-graphql-academy      10972
#  4           NaN  react-graphql-academy      10972
#  5           NaN  react-graphql-academy      10972  ]

# %%
locations = pd.concat(locations_list)

# %%
locations.sample(5)
# Out:
#        id              description  country.id country.name country.abbrev  \
# 1   16771          Porto, Portugal        28.0     Portugal             PT
# 12  16147            Lille, France        38.0       France             FR
# 4   16109            Paris, France        38.0       France             FR
# 2   15906  Buenos Aires, Argentina        60.0    Argentina             AR
# 26  16767            Paris, France        38.0       France             FR
#
#     city.id     city.name  city.keyword  state.id state.name state.abbrev  \
# 1   31102.0         Porto         porto       NaN        NaN          NaN
# 12  31128.0         Lille         lille       NaN        NaN          NaN
# 4   31136.0         Paris         paris       NaN        NaN          NaN
# 2   31171.0  Buenos Aires  buenos-aires       NaN        NaN          NaN
# 26  31136.0         Paris         paris       NaN        NaN          NaN
#
#    state.keyword              school  school_id
# 1            NaN  academia-de-codigo      10494
# 12           NaN            le-wagon      10868
# 4            NaN            ironhack      10828
# 2            NaN            le-wagon      10868
# 26           NaN            le-wagon      10868

# %%
#courses = pd.concat(courses_list)
#courses.head(10)

# %%
badges_list
# Out:
# [                name            keyword  \
#  0   Available Online   available_online
#  1  Verified Outcomes  verified_outcomes
#  2   Flexible Classes   flexible_classes
#
#                                           description    school  school_id
#  0          <p>School offers fully online courses</p>  ironhack      10828
#  1  <p>School publishes a third-party verified out...  ironhack      10828
#  2  <p>School offers part-time and evening classes...  ironhack      10828  ,
#                 name           keyword  \
#  0  Available Online  available_online
#  1  Flexible Classes  flexible_classes
#
#                                           description      school  school_id
#  0          <p>School offers fully online courses</p>  la-capsule      10853
#  1  <p>School offers part-time and evening classes...  la-capsule      10853  ,
#                 name           keyword  \
#  0  Available Online  available_online
#  1  Flexible Classes  flexible_classes
#  2     Job Guarantee     job_guarantee
#
#                                           description       school  school_id
#  0          <p>School offers fully online courses</p>  app-academy      10525
#  1  <p>School offers part-time and evening classes...  app-academy      10525
#  2             <p>School guarantees job placement</p>  app-academy      10525  ,
#                 name           keyword  \
#  0  Available Online  available_online
#  1  Flexible Classes  flexible_classes
#  2     Job Guarantee     job_guarantee
#
#                                           description       school  school_id
#  0          <p>School offers fully online courses</p>  springboard      11035
#  1  <p>School offers part-time and evening classes...  springboard      11035
#  2             <p>School guarantees job placement</p>  springboard      11035  ,
#                 name           keyword  \
#  0  Available Online  available_online
#  1  Flexible Classes  flexible_classes
#
#                                           description school  school_id
#  0          <p>School offers fully online courses</p>  metis      10886
#  1  <p>School offers part-time and evening classes...  metis      10886  ,
#                 name           keyword  \
#  0  Available Online  available_online
#  1     Job Guarantee     job_guarantee
#
#                                   description               school  school_id
#  0  <p>School offers fully online courses</p>  practicum-by-yandex      11225
#  1     <p>School guarantees job placement</p>  practicum-by-yandex      11225  ,
#                 name           keyword  \
#  0  Available Online  available_online
#  1  Flexible Classes  flexible_classes
#
#                                           description    school  school_id
#  0          <p>School offers fully online courses</p>  le-wagon      10868
#  1  <p>School offers part-time and evening classes...  le-wagon      10868  ,
#  Empty DataFrame
#  Columns: [school, school_id]
#  Index: [],
#                 name           keyword  \
#  0  Available Online  available_online
#  1  Flexible Classes  flexible_classes
#
#                                           description                 school  \
#  0          <p>School offers fully online courses</p>  react-graphql-academy
#  1  <p>School offers part-time and evening classes...  react-graphql-academy
#
#     school_id
#  0      10972
#  1      10972  ]

# %%
badges_raw = pd.concat(badges_list)
badges_raw = badges_raw.drop_duplicates(subset=['name'])
badges_raw
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 2             <p>School guarantees job placement</p>  app-academy      10525

# %%
# superstore.insert(0,'Profitable?',(superstore['Profit'].apply(profitable)))

def badges_m(row):
    if row == 'Available Online':
        return 1
    elif row == 'Verified Outcomes':
        return 2
    elif row == 'Flexible Classes':
        return 3
    elif row == 'Job Guarantee':
        return 4

# %%
badges_raw.insert(0,'badges_id',(badges_raw['name'].apply(badges_m)))

# %%
badges = badges_raw

# %%
badges
# Out:
#    badges_id               name            keyword  \
# 0          1   Available Online   available_online
# 1          2  Verified Outcomes  verified_outcomes
# 2          3   Flexible Classes   flexible_classes
# 2          4      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 2             <p>School guarantees job placement</p>  app-academy      10525

# %%
badges.columns = ['badges_id','name','keyword','description','school','school_id']

# %%
clean_badges = badges[['badges_id','name']]

# %%
display(clean_badges)
# Out:
#    badges_id               name
# 0          1   Available Online
# 1          2  Verified Outcomes
# 2          3   Flexible Classes
# 2          4      Job Guarantee

# %%
clean_schools = locations[['school_id','school']]
clean_schools.columns = ['schools_id','name']
clean_schools = clean_schools.drop_duplicates(subset=['schools_id'])

# %%
clean_schools
# Out:
#    schools_id                   name
# 0       10828               ironhack
# 0       10853             la-capsule
# 0       10525            app-academy
# 0       11035            springboard
# 0       10886                  metis
# 0       11225    practicum-by-yandex
# 0       10868               le-wagon
# 0       10494     academia-de-codigo
# 0       10972  react-graphql-academy

# %%
sub_df = pd.concat(badges_list)
clean_badges_schools = sub_df[['name','school_id']]
clean_badges_schools = clean_badges_schools.merge(clean_badges,how='inner',on='name')
clean_badges_schools.insert(0,'school_badges_id',(range(1,20)))
clean_badges_schools = clean_badges_schools[['school_badges_id','school_id','badges_id']]
clean_badges_schools
# Out:
#     school_badges_id  school_id  badges_id
# 0                  1      10828          1
# 1                  2      10853          1
# 2                  3      10525          1
# 3                  4      11035          1
# 4                  5      10886          1
# 5                  6      11225          1
# 6                  7      10868          1
# 7                  8      10972          1
# 8                  9      10828          2
# 9                 10      10828          3
# 10                11      10853          3
# 11                12      10525          3
# 12                13      11035          3
# 13                14      10886          3
# 14                15      10868          3
# 15                16      10972          3
# 16                17      10525          4
# 17                18      11035          4
# 18                19      11225          4

# %%
comments
# Out:
#         id                     name  anonymous       hostProgramName  \
# 0   276568  Guilherme golabek brein      False                  None
# 1   276147          Charlotte Urvoy      False                  None
# 2   275972                Anonymous       True                  None
# 3   275872             Ahmad Khalaf      False                  None
# 4   275855        Morgane Favchtein      False                  None
# ..     ...                      ...        ...                   ...
# 29  238594              Tiago Gomes      False  Software Engineering
# 30  245212           Peter McCarthy      False                  None
# 31  245192                  Polly S      False  Software Engineering
# 32  238091          Francisco Gomes      False  Software Engineering
# 33  238051                Anonymous       True                  None
#
#     graduatingYear isAlumni                        jobTitle  \
# 0           2018.0    False                Senior Associate
# 1           2021.0    False                  UX UI Designer
# 2           2021.0    False
# 3           2021.0    False                Product Designer
# 4           2021.0    False                  UX UI Designer
# ..             ...      ...                             ...
# 29          2018.0     True              Software Developer
# 30          2018.0     True             Front End Developer
# 31          2018.0     True               Frontend engineer
# 32          2018.0     True                   Web Developer
# 33          2017.0     True  Freelance Designer / Developer
#
#                                         tagline  \
# 0                              Improper billing
# 1                          Riche et pragmatique
# 2                            Amazing experience
# 3                   Intense but good experience
# 4                        Very nice experience !
# ..                                          ...
# 29                    A life change experience.
# 30             ReactJS Academy part time course
# 31  Great intense week of learning and practice
# 32                            Totally worth it!
# 33                         Amazing Workshops!!!
#
#                                                  body  \
# 0   <span class="truncatable"><p></p><p>A year aft...
# 1   <span class="truncatable"><p></p><p>- La métho...
# 2   <span class="truncatable"><p></p><p>the UX/UI ...
# 3   <span class="truncatable"><p></p><p>When I sta...
# 4   <span class="truncatable"><p></p><p>The UX UI ...
# ..                                                ...
# 29  <p>The curriculum is really good, we really di...
# 30  <p>Brilliant course, covers absolutely everyth...
# 31  <span class="truncatable"><p>A week of encapsu...
# 32  <span class="truncatable"><p>I've attended 1-w...
# 33  <p>Awesome Mentors!You can boost your knowledg...
#
#                                               rawBody  ...   queryDate  \
# 0   <p>A year after completing my course, ironhack...  ...  2021-04-30
# 1   <p>- La m&eacute;thode d&#39;apprentissage est...  ...  2021-04-20
# 2   <p>the UX/UI bootcamp has been an amazing lear...  ...  2021-04-17
# 3   <p>When I started I was a little disappointed ...  ...  2021-04-15
# 4   <p>The UX UI Design bootcamp is a great way to...  ...  2021-04-14
# ..                                                ...  ...         ...
# 29  The curriculum is really good, we really dive ...  ...  2018-11-26
# 30  Brilliant course, covers absolutely everything...  ...  2018-11-23
# 31  A week of encapsulated learning, lots of infor...  ...  2018-11-23
# 32  I've attended 1-week in Lisbon, 1-week in Lond...  ...  2018-11-07
# 33  Awesome Mentors!You can boost your knowledge i...  ...  2017-12-21
#
#                                    program             user overallScore  \
# 0                Web Development Part-Time  {'image': None}          1.0
# 1                    UX/UI Design Bootcamp  {'image': None}          5.0
# 2                    UX/UI Design Bootcamp  {'image': None}          4.0
# 3                    UX/UI Design Bootcamp  {'image': None}          4.0
# 4                    UX/UI Design Bootcamp  {'image': None}          4.3
# ..                                     ...              ...          ...
# 29  1 Week React, Redux & GraphQL Bootcamp  {'image': None}          5.0
# 30      Part time React, Redux and GraphQL  {'image': None}          5.0
# 31  1 Week React, Redux & GraphQL Bootcamp  {'image': None}          4.7
# 32  1 Week React, Redux & GraphQL Bootcamp  {'image': None}          5.0
# 33                                    None  {'image': None}          5.0
#
#    comments overall curriculum jobSupport  \
# 0        []     1.0        1.0        1.0
# 1        []     5.0        5.0        5.0
# 2        []     5.0        4.0        3.0
# 3        []     4.0        4.0        4.0
# 4        []     5.0        4.0        4.0
# ..      ...     ...        ...        ...
# 29       []     5.0        5.0        5.0
# 30       []     5.0        5.0        NaN
# 31       []     5.0        4.0        5.0
# 32       []     5.0        5.0        5.0
# 33       []     5.0        5.0        5.0
#
#                                           review_body                 school
# 0   A year after completing my course, ironhack co...               ironhack
# 1   - La méthode d'apprentissage est l'une des mei...               ironhack
# 2   the UX/UI bootcamp has been an amazing learnin...               ironhack
# 3   When I started I was a little disappointed but...               ironhack
# 4   The UX UI Design bootcamp is a great way to tr...               ironhack
# ..                                                ...                    ...
# 29  The curriculum is really good, we really dive ...  react-graphql-academy
# 30  Brilliant course, covers absolutely everything...  react-graphql-academy
# 31  A week of encapsulated learning, lots of infor...  react-graphql-academy
# 32  I've attended 1-week in Lisbon, 1-week in Lond...  react-graphql-academy
# 33  Awesome Mentors!You can boost your knowledge i...  react-graphql-academy
#
# [5490 rows x 21 columns]

# %%
sub_df2 = clean_schools.rename(columns={'name':'school'})
clean_comments = comments.merge(sub_df2, how='inner', on='school')
display(clean_comments.columns)
to_drop = ['anonymous', 'hostProgramName', 'graduatingYear','jobTitle', 'tagline', 'body', 'rawBody', 'createdAt',
       'queryDate', 'user', 'comments', 'review_body','school']
clean_comments.drop(to_drop, inplace=True,axis=1)
clean_comments = clean_comments.fillna(0)
clean_comments['overall'] = clean_comments['overall'].apply(lambda x : float(x))
clean_comments['overallScore'] = clean_comments['overallScore'].apply(lambda x : float(x))
clean_comments['curriculum'] = clean_comments['curriculum'].apply(lambda x : float(x))
clean_comments['jobSupport'] = clean_comments['jobSupport'].apply(lambda x : float(x))
# Out:
# Index(['id', 'name', 'anonymous', 'hostProgramName', 'graduatingYear',
#        'isAlumni', 'jobTitle', 'tagline', 'body', 'rawBody', 'createdAt',
#        'queryDate', 'program', 'user', 'overallScore', 'comments', 'overall',
#        'curriculum', 'jobSupport', 'review_body', 'school', 'schools_id'],
#       dtype='object')
#           id                    name isAlumni  \
# 1822  232079              Timmy Jing     True
# 1776  244245        Brandon Woodruff     True
# 459   246547       Anna Antràs Marti     True
# 4177  255062                     Joe     True
# 1180  250895                  Benoit     True
# 2907  247814           Engin Turkmen     True
# 4768  244295                   Irvin     True
# 3080  244799  Prashaanth Jagannathan     True
# 131   265376         Mathias Gautier    False
# 4277  250707                   Dan A     True
#
#                                  program  overallScore  overall  curriculum  \
# 1822                                   0           5.0      5.0         5.0
# 1776  Software Engineer Track: In-Person           5.0      5.0         5.0
# 459      Full-time UX/UI Design Bootcamp           5.0      5.0         5.0
# 4177                                   0           4.7      5.0         5.0
# 1180                                   0           5.0      5.0         5.0
# 2907           Data Science Career Track           5.0      5.0         5.0
# 4768   FullStack program - 35+ locations           5.0      5.0         5.0
# 3080                                   0           4.7      5.0         5.0
# 131             Web Development Bootcamp           5.0      5.0         5.0
# 4277   FullStack program - 35+ locations           5.0      5.0         5.0
#
#       jobSupport  schools_id
# 1822         0.0       10525
# 1776         5.0       10525
# 459          5.0       10828
# 4177         4.0       10868
# 1180         5.0       10853
# 2907         5.0       11035
# 4768         0.0       10868
# 3080         4.0       11035
# 131          5.0       10828
# 4277         0.0       10868

# %%
locations_clean = locations.copy()
to_drop = ['description','country.id','country.abbrev','city.id','city.keyword','state.id','state.name','state.abbrev','state.keyword']
locations_clean.drop(to_drop,inplace=True,axis=1,)
locations_clean.rename(columns = {'id':'location_id','country.name':'country','city.name':'city'}, inplace = True)

# %%
clean_locations = locations_clean
clean_locations = clean_locations.fillna('Online')

# %%
clean_locations = clean_locations[['location_id','country','city','school_id']]

# %%
display(clean_schools)
display(clean_badges)
display(clean_badges_schools)
display(clean_comments)
display(clean_locations)
# Out:
#    schools_id                   name
# 0       10828               ironhack
# 0       10853             la-capsule
# 0       10525            app-academy
# 0       11035            springboard
# 0       10886                  metis
# 0       11225    practicum-by-yandex
# 0       10868               le-wagon
# 0       10494     academia-de-codigo
# 0       10972  react-graphql-academy
#    badges_id               name
# 0          1   Available Online
# 1          2  Verified Outcomes
# 2          3   Flexible Classes
# 2          4      Job Guarantee
#     school_badges_id  school_id  badges_id
# 0                  1      10828          1
# 1                  2      10853          1
# 2                  3      10525          1
# 3                  4      11035          1
# 4                  5      10886          1
# 5                  6      11225          1
# 6                  7      10868          1
# 7                  8      10972          1
# 8                  9      10828          2
# 9                 10      10828          3
# 10                11      10853          3
# 11                12      10525          3
# 12                13      11035          3
# 13                14      10886          3
# 14                15      10868          3
# 15                16      10972          3
# 16                17      10525          4
# 17                18      11035          4
# 18                19      11225          4
#           id                     name isAlumni  \
# 0     276568  Guilherme golabek brein    False
# 1     276147          Charlotte Urvoy    False
# 2     275972                Anonymous    False
# 3     275872             Ahmad Khalaf    False
# 4     275855        Morgane Favchtein    False
# ...      ...                      ...      ...
# 5485  238594              Tiago Gomes     True
# 5486  245212           Peter McCarthy     True
# 5487  245192                  Polly S     True
# 5488  238091          Francisco Gomes     True
# 5489  238051                Anonymous     True
#
#                                      program  overallScore  overall  \
# 0                  Web Development Part-Time           1.0      1.0
# 1                      UX/UI Design Bootcamp           5.0      5.0
# 2                      UX/UI Design Bootcamp           4.0      5.0
# 3                      UX/UI Design Bootcamp           4.0      4.0
# 4                      UX/UI Design Bootcamp           4.3      5.0
# ...                                      ...           ...      ...
# 5485  1 Week React, Redux & GraphQL Bootcamp           5.0      5.0
# 5486      Part time React, Redux and GraphQL           5.0      5.0
# 5487  1 Week React, Redux & GraphQL Bootcamp           4.7      5.0
# 5488  1 Week React, Redux & GraphQL Bootcamp           5.0      5.0
# 5489                                       0           5.0      5.0
#
#       curriculum  jobSupport  schools_id
# 0            1.0         1.0       10828
# 1            5.0         5.0       10828
# 2            4.0         3.0       10828
# 3            4.0         4.0       10828
# 4            4.0         4.0       10828
# ...          ...         ...         ...
# 5485         5.0         5.0       10972
# 5486         5.0         0.0       10972
# 5487         4.0         5.0       10972
# 5488         5.0         5.0       10972
# 5489         5.0         5.0       10972
#
# [5490 rows x 9 columns]
#     location_id      country         city  school_id
# 0         15901      Germany       Berlin      10828
# 1         16022       Mexico  Mexico City      10828
# 2         16086  Netherlands    Amsterdam      10828
# 3         16088       Brazil    Sao Paulo      10828
# 4         16109       France        Paris      10828
# ..          ...          ...          ...        ...
# 1         16749     Portugal       Lisbon      10972
# 2         17023  Netherlands    Amsterdam      10972
# 3         17242       Online       Online      10972
# 4         17251      Germany       Berlin      10972
# 5         17252        Spain    Barcelona      10972
#
# [80 rows x 4 columns]

# %%
#################CREATING A CONNECTION TO THE DATABASE#####################
import pymysql
import getpass
import mysql.connector
from sqlalchemy import create_engine

# Connect to the database

host="database-1.cesj3b2ko52z.us-east-2.rds.amazonaws.com"
port=3306
dbname="project"
user="root"
password="12345678"


#engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
#                       .format(user="root",
#                               pw="1234",
#                               db="project"))

engine = create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'
            .format(user, password,host, dbname)).connect()


# create cursor

# %%
clean_comments.to_sql('comments', con = engine,if_exists = 'replace')

# %%
clean_schools.to_sql('schools', con = engine,if_exists = 'replace')

# %%
clean_badges.to_sql('badges', con = engine,if_exists = 'replace')

# %%
clean_badges_schools.to_sql('school_badges_id', con = engine,if_exists = 'replace')

# %%
clean_locations.to_sql('locations', con = engine,if_exists = 'replace')

# %%
query = pd.read_sql_query("""SELECT AVG(ct.overallScore) AS overallScore, sc.name, ct.schools_id
FROM comments ct
JOIN schools sc
ON ct.schools_id = sc.schools_id
GROUP BY ct.schools_id
ORDER BY overallScore DESC;""", engine)

# %%
overall_score = query

# %%
total_reviews
# Out:
#    Total_reviews                   name
# 0           1979               le-wagon
# 1           1054            app-academy
# 2           1045               ironhack
# 3            923            springboard
# 4            159             la-capsule
# 5            117                  metis
# 6             97     academia-de-codigo
# 7             82    practicum-by-yandex
# 8             34  react-graphql-academy

# %%
overall_score
# Out:
#    overallScore                   name  schools_id
# 0      4.987421             la-capsule       10853
# 1      4.960825     academia-de-codigo       10494
# 2      4.927792               le-wagon       10868
# 3      4.821368                  metis       10886
# 4      4.801914               ironhack       10828
# 5      4.764706  react-graphql-academy       10972
# 6      4.728049    practicum-by-yandex       11225
# 7      4.586433            app-academy       10525
# 8      4.564139            springboard       11035

# %%
labels = ["Very Low", "Low", "Moderate", "High", "Very High"]

qbins = pd.qcut(overall_score['overallScore'],5, labels=labels)

# %%
overall_score['qcut'] = qbins

# %%
overall_score = overall_score[['overallScore','name','qcut']]

# %%
overall_score
# Out:
#    overallScore                   name       qcut
# 0      4.987421             la-capsule  Very High
# 1      4.960825     academia-de-codigo  Very High
# 2      4.927792               le-wagon       High
# 3      4.821368                  metis       High
# 4      4.801914               ironhack   Moderate
# 5      4.764706  react-graphql-academy        Low
# 6      4.728049    practicum-by-yandex        Low
# 7      4.586433            app-academy   Very Low
# 8      4.564139            springboard   Very Low
